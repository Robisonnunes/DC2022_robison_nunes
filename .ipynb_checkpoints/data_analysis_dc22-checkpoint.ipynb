# %% [markdown]
# ![Clean%20Work%20Place%20LinkedIn%20Banner%20%281%29%20(1)%20(1)%20(1).png](attachment:Clean%20Work%20Place%20LinkedIn%20Banner%20%281%29%20(1)%20(1)%20(1).png)

# %% [markdown]
# ## <font color=green>  1 -  BUSINESS UNDERSTANDING</font>

# %% [markdown]
# #### <font color=green>  Descrição do case</font>
#
# A Stone tem como objetivo ajudar o empreendedor brasileiro a vender, gerir e crescer
# seu negócio através dos nossos produtos e serviços que vão desde a maquininha de cartão de crédito à sistemas ERP para gestão.
#
# Um dos produtos que oferecemos aos nossos clientes é o crédito, voltado para facilitar
# a vida do lojista e impulsionar o crescimento do seu negócio. A Stone trabalha desde 2019 para construir um produto sólido e maduro. Mesmo no momento mais intenso da pandemia provocada pela COVID-19, em 3 anos, já liberamos mais de 190 mil linhas de crédito, que somam mais de 3,4 bilhões de reais desembolsados para apoiar nossos clientes a crescer e manter seus negócios.
#
# Nosso produto é diferenciado: os clientes pagam seus empréstimos através de um
# percentual de retenção aplicado sobre as transações realizadas pela maquininha de
# cartão Stone. Desta forma, conseguimos promover um pagamento sustentável do empréstimo
# que acompanha as variações de fluxo de caixa do lojista, que não precisa se comprometer com um valor fixo que possa pesar em um mês de baixo movimento em seu negócio. Um cliente pode ter mais de um contrato de empréstimo simultâneo, desde que o contrato anterior esteja em dia.
#
# Durante a pandemia, naturalmente tivemos um aumento de clientes inadimplentes, ou
# seja, com problemas no pagamento de seus contratos e, consequentemente, sentimos a
# necessidade de evoluir nossas ações de comunicação e acionamento para recuperação
# dos saldos devedores que alguns clientes passaram a deixar em aberto.
#
# Dentro desta evolução, uma das ações tomadas internamente foi refinar nossas
# estratégias de comunicação com os clientes, visando recuperar clientes que apresentavam
# problemas no ritmo de pagamento, e claro, sempre usando dados para melhor guiar nossas
# decisões!
#
# Qual é a curva ideal de vezes que acionamos um cliente?
#
# Quando um cliente começa a apresentar dificuldade na liquidação de seus contratos, ele
# passa a ser elegível para ser acionado por nossa régua de comunicação com intuito de
# estimular a retomada do ritmo saudável de pagamento de acordo com o perfil e o momento de
# cada cliente.
#
# As comunicações são disparadas por contrato, sendo assim, um cliente pode
# receber diversas comunicações com diferentes conteúdos, um para cada momento da jornada
# de seu respectivo contrato. Desde o envio da comunicação até o recebimento, são gerados flags
# que indicam o engajamento do cliente com as comunicações da seguinte forma:
#
# 1. Envio do comunicado > 2. Comunicado recebido > 3.Comunicado lido
#
# Dada a sequência da comunicação acima, ocasionalmente são observados erros no
# processo de envio do comunicado, gerando um percentual (%) de falhas por diversos
# motivos (servidor indisponível, número incorreto etc.). Após o envio bem-sucedido, observamos
# também que nem todos os comunicados são lidos.
#
# Além do engajamento do cliente com as comunicações, temos outra questão importante:
# a efetividade na recuperação dos contratos ativos. Uma comunicação eficaz é aquela que
# estimula e converte um cliente com problemas na liquidação do seu contrato a retomar
# o pagamento saudável, seja por meio de quitação ou do retorno ao ritmo de transação
# esperado.
#
# Para mensurar a efetividade de uma ação, temos dois ótimos termômetros: os dias sem
# pagamento (dsp) e os dias sem pagamento do principal de um cliente (dspp).
#
# Os dias sem pagamento (dsp) representam o total de dias corridos que um contrato
# apresenta sem realizar nenhum pagamento.
#
# Já os dias sem pagamento do principal (dspp),
# representam o total de dias corridos que um contrato apresenta sem reduzir o valor do saldo
# principal. Neste último conceito, mesmo que o contrato apresente algum pagamento, se este montante não for suficiente para cobrir juros + impostos, valores deduzidos prioritariamente,
# o saldo principal do contrato permanecerá sem pagamento.
#
# Dado o problema apresentado, queremos que você nos conte qual a sua abordagem
# para analisar os dados disponibilizados a fim de entender e explorar a curva de engajamento
# x quantidade de acionamentos e nos traga insights sobre a efetividade destas ações em
# termos de pagamento.
#
# Consideramos um diferencial a exploração de variáveis complementares (ex. ramo do
# lojista, dados geográficos, sazonalidade etc.) para entender se existem diferentes curvas para
# diferentes perfis, visando customizar as ações de comunicação de acordo com o perfil de cada
# cliente.
#
# Estas análises extras também podem (e devem) se estender a performance de
# pagamento e efetividade das ações de cobrança.
#
# A régua de acionamento
#
# Para este hackathon, criamos uma régua de comunicação simplificada para
# determinar quais ações de comunicação cada cliente receberá de acordo com seu momento de
# inadimplência a partir dos dias sem pagamento (dsp) e dias sem pagamento de principal (dspp).
#
# Conforme demonstrado abaixo, de acordo com os dias de inadimplência de um contrato,
# ele receberá um tipo de campanha diferente com intuito de estimular o retorno saudável de
# pagamento ou realizar a quitação do saldo devedor:
#
# ![rwgua.png](attachment:rwgua.png)
#
# #### <font color=green>  O que devo responder!</font>
#
# Dado o problema apresentado e os dados disponíveis, esperamos que você seja capaz
# de chegar a uma resposta sobre <font color=green>“Qual é a curva ideal de vezes que devemos acionar um cliente?”.</font>
#
# Também esperamos que você seja capaz de criar análises adicionais relacionadas ao
# tema apresentado, explorando todos os dados disponibilizados, usando bases de dados
# públicas e inovando! Esse é o nosso espírito Stone! \o/

# %% [markdown]
# ## <font color=green>  2 -  DATA UNDERSTANDING</font>

# %% [markdown]
# #### <font color=green>  Base PORTFOLIO_GERAL.csv</font>
#
# Esta tabela contém uma amostra aleatória do histórico de alguns contratos de crédito. Ou
# seja, cada contrato contém N registros, um para cada dia do histórico do contrato desde o
# momento de sua originação.
#
# #### <font color=green>  Base PORTFOLIO_TPV.csv</font>
# Esta base de dados possui informações dos registros de transações relacionadas à
# maquininha Stone do cliente, onde é possível amortizar o empréstimo através das transações
# e pode ser utilizada para entender a performance de pagamento de forma geral.
#
# #### <font color=green>  Base PORTFOLIO_COMUNICADOS.csv</font>
# Aqui você encontrará todas as informações relacionadas às ações de comunicação enviadas
# aos clientes bem como seu respectivo status e demais informações.
#
# #### <font color=green>  Base PORTFOLIO_CLIENTES.csv</font>
# E nesta tabela você encontrará todas as informações relacionadas aos dados cadastrais dos
# clientes que contrataram empréstimos, bem como suas respectivas informações geográficas
# e de s

# %% [markdown]
# ![Screenshot%20from%202022-04-28%2022-49-20.png](attachment:Screenshot%20from%202022-04-28%2022-49-20.png)

# %%
# Bibliotecas usadas no projeto
import pandas as pd
import functools
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings("ignore")

# %%
#functions construidas para esse projeto
def info_data(data):
    
    """ please inform dataset - função criada para visualizar as principais métricas dos datasets"""
    
    missing = pd.DataFrame(data = (data.isnull().sum()/len(data))*100, columns=['% missing'])
    unique = pd.DataFrame(data=data.nunique(), columns=['unique'])
    count = pd.DataFrame(data=data.count(), columns=['count'])
    types = pd.DataFrame(data=data.dtypes, columns=['types'])
    dfs = [types,count, missing, unique]
    info = functools.reduce(lambda left,right: pd.merge(left,right,left_index=True, right_index=True), dfs)
    info['duplicated'] = info['count'] - info['unique']
    return info

def varqual(data, col, order, title):    
    """ Plotar um gráfico de freq. (argumentos: dataset, feature, title, ordenamento)"""
    print(col)
    print('*' * 80, '\n')
    print(((data[col].value_counts(normalize=True)*100)).round(2))

    fig, (ax1) = plt.subplots(1,1 ,figsize=(18,5))
    ax = sns.countplot(data = data, x = col, order=order,palette='crest')
    ax.set_title(title)
    
    for i in ax.patches:
        ax.annotate(i.get_height(),
                    (i.get_x() + i.get_width() / 2, i.get_height()),
                    ha='center',
                    va='baseline',
                    fontsize=12,
                    color='black',
                    xytext=(0, 1),
                    textcoords='offset points')    
    plt.show() 

def qual_qual(data, col, col2 ):
    """ Plota gráfico de barras (argumentos: dataset, feature, feature_target)"""
    analise_qual = data.groupby([col, col2]).size().unstack()
    ax = (analise_qual.T*100/analise_qual.T.sum()).T.plot(kind='bar',
    figsize=(15,6),width=0.8, color=['gray', 'green','greenyellow','red'],stacked=True, rot=0 )
    ax.set_title('Relaçao entre ' + col + ' x ' + col2, fontsize=15)
    
    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x ,y = p.get_xy()
        ax.annotate('{:.2f}%'.format(height), (x + width/2, y + height*0.2),
                    ha='center',
                    fontsize=15,
                    color='black',
                    xytext=(0, 1),
                    textcoords='offset points')
    
    plt.legend(fontsize=12, 
    bbox_to_anchor = (1.05, 0.6))
    
    plt.show()

# %% [markdown]
# ### <font color=green>  2.1 -  LOAD DATASETS</font>
#
# - Etapa de carregamento e visualizalçao dos dados

# %%
# Base PORTFOLIO_GERAL.csv
p_geral = pd.read_csv('Dados_etc/portfolio_geral.csv', sep=',', encoding='utf-8')

# Visualizando os dados
pd.set_option('display.max_columns', None)
p_geral.head(3)
# Out:
#                         contrato_id dt_ref_portfolio    safra  \
# 0  356c02706c8e74b15004bb5964ade6bb       2022-03-01  2020-06
# 1  1eb0e13f83f336146227ccc9efb08c47       2022-03-01  2020-07
# 2  8b03675f597974ca96f06648e96af6d4       2022-03-01  2020-08
#
#                        nr_documento status_contrato dt_contrato dt_desembolso  \
# 0  b0871d4e0d72afd1d44381e5b2453cb2         Settled  2020-06-24    2020-06-29
# 1  938513461b4a4fcd2bf99ffd8f12b9be         Settled  2020-07-26    2020-07-28
# 2  4303bd71ee3fe80aba4efc8dbd6c7d70         Settled  2020-08-13    2020-08-17
#
#   dt_vencimento       dt_wo  prazo  vlr_desembolsado  vlr_tarifa  juros_mes  \
# 0    2020-12-24  2021-12-24  10.26          22686.57         0.0    0.10788
# 1    2021-10-26  2022-10-26  25.65          16074.00         0.0    0.04788
# 2    2022-02-13  2023-02-13  30.78          17100.00         0.0    0.05388
#
#    juros_diario  perc_retencao  vlr_pgto_realizado  vlr_pgto_esperado  \
# 0       0.00345        0.24000                 0.0             163.00
# 1       0.00157        0.08400                 0.0              46.87
# 2       0.00176        0.08076                 0.0              45.57
#
#    vlr_saldo_devedor  vlr_saldo_devedor_esperado  dsp  dspp  flag_transacao
# 0               0.55                         0.0    0     0               0
# 1               0.00                         0.0    0     0               0
# 2               0.00                         0.0    0     0               0

# %%
# Base PORTFOLIO_TPV.csv
p_tpv = pd.read_csv('Dados_etc/portfolio_tpv.csv', sep=',', encoding='utf-8')

# Visualizando os dados
p_tpv.head(3)
# Out:
#                        nr_documento  dt_transacao  qtd_transacoes  vlr_tpv
# 0  7f0464355620bc7c137b3546eb90867a      20210505               4    116.5
# 1  7f0464355620bc7c137b3546eb90867a      20210506              20    537.0
# 2  7f0464355620bc7c137b3546eb90867a      20210507              17    440.0

# %%
# Base PORTFOLIO_CLIENTES.csv
p_clientes = pd.read_csv('Dados_etc/portfolio_clientes.csv', sep=',', encoding='utf-8')

# Visualizando os dados
p_clientes.head(3)
# Out:
#                        nr_documento tipo_empresa            cidade estado  \
# 0  094aaed740bbd7fcddb6c678c18d883a           PJ           Caucaia     CE
# 1  eaade7915611fcdcbba747e3a83365c6           PF  Cidade Ocidental     GO
# 2  1f21958fd296f1b04a1f0c2658913856          MEI            Manaus     AM
#
#           subsegmento     segmento
# 0  Alimentação Rápida  Alimentação
# 1      Lojas Diversas       Varejo
# 2  Alimentação Rápida  Alimentação

# %%
# Base PORTFOLIO_COMUNICADOS.csv
p_comunicados = pd.read_csv('Dados_etc/portfolio_comunicados.csv', sep=',', encoding='utf-8')

# Visualizando os dados
p_comunicados.head(3)
# Out:
#                         contrato_id dt_ref_portfolio   data_acao tipo_acao  \
# 0  0d823ddff1839eb938dccc68586ae365       2021-01-16  2021-01-18       HSM
# 1  c2f8a21671dbaeaa4157e03682c639e1       2021-05-22  2021-05-24       HSM
# 2  e19a222c233d46ff4984489c13aa1b98       2020-09-15  2020-09-15       HSM
#
#                  acao        status
# 0  campanhaobservacao          LIDO
# 1  campanhaobservacao      ENTREGUE
# 2  campanhaobservacao  NAO ENTREGUE

# %% [markdown]
# ### <font color=green>  2.2 -  EXPLORATORY DATA ANALYSIS</font>
#
# - Inicio da exploracao, conhecendo os dados e algumas metricas importantes

# %%
# invocando a função info_data (ver seção functions acima)
info_data(p_geral)
# Out:
#                               types    count  % missing   unique  duplicated
# contrato_id                  object  8061006        0.0    14756     8046250
# dt_ref_portfolio             object  8061006        0.0      838     8060168
# safra                        object  8061006        0.0       18     8060988
# nr_documento                 object  8061006        0.0    14265     8046741
# status_contrato              object  8061006        0.0        6     8061000
# dt_contrato                  object  8061006        0.0      526     8060480
# dt_desembolso                object  8061006        0.0      355     8060651
# dt_vencimento                object  8061006        0.0      736     8060270
# dt_wo                        object  8061006        0.0      736     8060270
# prazo                       float64  8061006        0.0        8     8060998
# vlr_desembolsado            float64  8061006        0.0     8784     8052222
# vlr_tarifa                  float64  8061006        0.0      772     8060234
# juros_mes                   float64  8061006        0.0       28     8060978
# juros_diario                float64  8061006        0.0       28     8060978
# perc_retencao               float64  8061006        0.0     2301     8058705
# vlr_pgto_realizado          float64  8061006        0.0   111430     7949576
# vlr_pgto_esperado           float64  8061006        0.0    12643     8048363
# vlr_saldo_devedor           float64  8061006        0.0  2879232     5181774
# vlr_saldo_devedor_esperado  float64  8061006        0.0  3050274     5010732
# dsp                           int64  8061006        0.0      792     8060214
# dspp                          int64  8061006        0.0      834     8060172
# flag_transacao                int64  8061006        0.0        2     8061004

# %%
# invocando a função info_data (ver seção functions acima)
info_data(p_tpv)
# Out:
#                   types    count  % missing  unique  duplicated
# nr_documento     object  4408597        0.0   14259     4394338
# dt_transacao      int64  4408597        0.0     547     4408050
# qtd_transacoes    int64  4408597        0.0     705     4407892
# vlr_tpv         float64  4408597        0.0  492049     3916548

# %%
# invocando a função info_data (ver seção functions acima)
info_data(p_clientes)
# Out:
#                types  count  % missing  unique  duplicated
# nr_documento  object  14405        0.0   14265         140
# tipo_empresa  object  14405        0.0       3       14402
# cidade        object  14405        0.0    1502       12903
# estado        object  14405        0.0      28       14377
# subsegmento   object  14405        0.0      16       14389
# segmento      object  14405        0.0       9       14396

# %%
# invocando a função info_data (ver seção functions acima)
info_data(p_comunicados)
# Out:
#                    types   count  % missing  unique  duplicated
# contrato_id       object  403740        0.0   12202      391538
# dt_ref_portfolio  object  403740        0.0     830      402910
# data_acao         object  403740        0.0     594      403146
# tipo_acao         object  403740        0.0       2      403738
# acao              object  403740        0.0       5      403735
# status            object  403740        0.0       4      403736

# %% [markdown]
# ## <font color=green>  3 -  ETL</font>
#
# - Preparacao dos datasets para os joins e construcao de tabela unica para insights e análise

# %% [markdown]
# ### <font color=green>  3.1 -  PORTIFÓLIO COMUNICADOS</font>

# %%
#ELT - COMUNICADOS ==================================================================================

# Salvando em novo objeto para manter o histórico e viabilizar um row back
p_comunicados1 = p_comunicados

# Criando chave única para merge na granularidade de data relacionamento de um contrato
#dentro da tabela portifólio geral
p_comunicados1['pk_comunicados'] = p_comunicados1['contrato_id'] + '-'+ p_comunicados1['dt_ref_portfolio']

# Ordenando os dados
p_comunicados1 = p_comunicados1.sort_values(by=['pk_comunicados', 'tipo_acao'])

# reconstruindo o index
p_comunicados1 = p_comunicados1.reset_index(drop=True)

# For para agrupar em uma linha o tipo de acao e flag de engajamento da mesma na granularidade de data
p_comunicados1['tp_acao1'] = ''
p_comunicados1['st_acao1'] = ''
p_comunicados1['tp_acao2'] = ''
p_comunicados1['st_acao2'] = ''

for i in range(len(p_comunicados1)-1):
    if p_comunicados1['pk_comunicados'][i] == p_comunicados1['pk_comunicados'][i+1]:
        p_comunicados1['tp_acao1'][i] =  p_comunicados1['tipo_acao'][i]
        p_comunicados1['st_acao1'][i] =  p_comunicados1['status'][i]
        p_comunicados1['tp_acao2'][i] =  p_comunicados1['tipo_acao'][i+1]
        p_comunicados1['st_acao2'][i] =  p_comunicados1['status'][i+1]
        i += 2
    else:
        if p_comunicados1['tp_acao1'][i] == 'EMAIL':
            p_comunicados1['tp_acao1'][i] =  p_comunicados1['tipo_acao'][i] 
            p_comunicados1['st_acao1'][i] =  p_comunicados1['status'][i]
        else:        
            p_comunicados1['tp_acao2'][i] =  p_comunicados1['tipo_acao'][i]
            p_comunicados1['st_acao2'][i] =  p_comunicados1['status'][i]
        i += 1

# Eliminando as linhas duplicadas que sobraram após o for acima
p_comunicados1 = p_comunicados1.drop_duplicates(subset='pk_comunicados', keep='first')

# reconstruindo o index
p_comunicados1 = p_comunicados1.reset_index(drop=True)

# Elimando colunas redundantes
p_comunicados1.drop(columns=['tipo_acao','status'], inplace=True)

# salvando o output do etl
p_comunicados1.to_csv('p_comunicados.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ### <font color=green>  3.2 -  PORTIFÓLIO TPV</font>

# %%
#ELT - TPV ========================================================================================

# Salvando em novo objeto para manter o histórico e viabilizar um row back
p_tpv1 = p_tpv

#Corrigindo o formato da data
p_tpv1['dt_transacao'] = pd.to_datetime(p_tpv1['dt_transacao'], format='%Y%m%d', errors='ignore')
p_tpv1['dt_transacao'] = p_tpv1['dt_transacao'].astype(str)

# Criando chave unica
p_tpv1['pk_tpv'] = p_tpv1['nr_documento'] + '-'+ p_tpv1['dt_transacao']

# salvando o output do etl
p_tpv1.to_csv('p_tpv.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ### <font color=green>  3.3 -  PORTIFÓLIO CLIENTES</font>

# %%
#ELT - PORTIFÓLIO CLIENTES==========================================================================

# Salvando em novo objeto para manter o histórico e viabilizar um row back
p_clientes1 = p_clientes

# Excluindo as linhas duplicadas
p_clientes1.drop_duplicates(subset='nr_documento', keep='first', inplace=True)                                                                       

#  salvando o output do etl
p_clientes1.to_csv('p_clientes.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ### <font color=green>  3.4 -  CRIACAO DA BASE ÚNICA</font>

# %%
#ELT - BASE ÚNICA ==================================================================================

# Load dos datasets transformados pelas etapas de ETL acima
p_comunicados1 =  pd.read_csv('p_comunicados.csv', sep=',', encoding='utf-8') 
p_tpv1 =  pd.read_csv('p_tpv.csv', sep=',', encoding='utf-8')
p_clientes1 =  pd.read_csv('p_clientes.csv', sep=',', encoding='utf-8')

# Criação das chaves estrangeiras no portifólio geral
p_geral['pk_comunicados'] = p_geral['contrato_id'] + '-'+ p_geral['dt_ref_portfolio']
p_geral['pk_tpv'] = p_geral['nr_documento'] + '-'+ p_geral['dt_ref_portfolio']

# Join portifolio geral x portifolio comunicados atribuindo ao objeto df
df = p_geral.merge(p_comunicados1, how='left', on='pk_comunicados')

# Join do objeto df x portifolio tpv
df = df.merge(p_tpv1, how='left', on='pk_tpv')

# Corrigindo a chave estrangeira no objeto df para o join com o portfolio clientes
df.rename(columns={'nr_documento_x':'nr_documento'}, inplace=True)

# Join do objeto df x portifolio clientes
df = df.merge(p_clientes1, how='left', on='nr_documento')

# Corrigindo o nome de colunas e eliminando as colunas desnecessárias
df.rename(columns={'contrato_id_x':'contrato_id','dt_ref_portfolio_x':'dt_ref_portfolio'}, inplace=True)
df.drop(columns=['pk_comunicados','pk_tpv','contrato_id_y','dt_ref_portfolio_y','nr_documento_y'], inplace=True)

# %% [markdown]
# ### <font color=green>  3.5 -  ENRIQUECIMENTO COM FONTES EXTERNAS</font>

# %%
#ELT - ENRIQUECIMENTO DE FONTES EXTERNAS ============================================================
# Load dos dados externos do ibge por uf 
ext_data = pd.read_csv('indices_por_uf_ibge.csv', sep=',', encoding='utf-8')

# drop das colunas indexadoras 
ext_data.drop(columns=['UF', 'Código'], inplace=True)

# Correçao do tipo de dados (numericos e datas)
ext_data['Densidade demográfica [2010]'] = pd.to_numeric(ext_data['Densidade demográfica [2010]'].str.replace(',','.'))
ext_data['IDH[2010]'] = pd.to_numeric(ext_data['IDH[2010]'].str.replace(',','.'))
ext_data['balanco_financeiro- R$ (×1000) [2017]'] = pd.to_numeric(ext_data['balanco_financeiro- R$ (×1000) [2017]'].str.replace(',','.'))
df['dt_transacao'] = pd.to_datetime(df['dt_transacao'])
df['dt_ref_portfolio'] = pd.to_datetime(df['dt_ref_portfolio'])
df['data_acao'] = pd.to_datetime(df['data_acao'])
df['dt_contrato'] = pd.to_datetime(df['dt_contrato'])
df['dt_desembolso'] = pd.to_datetime(df['dt_desembolso'])
df['dt_vencimento'] = pd.to_datetime(df['dt_vencimento'])
df['dt_wo'] = pd.to_datetime(df['dt_wo'])


# Join do objeto df x portifolio clientes
df = df.merge(ext_data, how='left', on='estado')

# salvando o output do etl geral *portifolio_full_csv
df.to_csv('portifolio_full.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ## <font color=green>  4 - DATA ANALYSIS</font>
#
# - Parte de Análise da curva de engajamento x quantidade de acionamentos, exploração de diferentes perfis e efetividade de pagamento

# %%
# Load base única gerado pelo processo de ETL
df = pd.read_csv('portifolio_full.csv', sep=',', encoding='utf-8')

# %%
info_data(df)
# Out:
#                                                       types    count  \
# contrato_id                                          object  8061006
# dt_ref_portfolio                                     object  8061006
# safra                                                object  8061006
# nr_documento                                         object  8061006
# status_contrato                                      object  8061006
# dt_contrato                                          object  8061006
# dt_desembolso                                        object  8061006
# dt_vencimento                                        object  8061006
# dt_wo                                                object  8061006
# prazo                                               float64  8061006
# vlr_desembolsado                                    float64  8061006
# vlr_tarifa                                          float64  8061006
# juros_mes                                           float64  8061006
# juros_diario                                        float64  8061006
# perc_retencao                                       float64  8061006
# vlr_pgto_realizado                                  float64  8061006
# vlr_pgto_esperado                                   float64  8061006
# vlr_saldo_devedor                                   float64  8061006
# vlr_saldo_devedor_esperado                          float64  8061006
# dsp                                                   int64  8061006
# dspp                                                  int64  8061006
# flag_transacao                                        int64  8061006
# data_acao                                            object   190474
# acao                                                 object   190474
# tp_acao1                                             object   190474
# st_acao1                                             object   190474
# tp_acao2                                             object   190474
# st_acao2                                             object   190474
# dt_transacao                                         object  2403306
# qtd_transacoes                                      float64  2403306
# vlr_tpv                                             float64  2403306
# tipo_empresa                                         object  8061006
# cidade                                               object  8061006
# estado                                               object  8061006
# subsegmento                                          object  8061006
# segmento                                             object  8061006
# População estimada - pessoas [2021]                 float64  8059760
# Densidade demográfica [2010]                        float64  8059760
# Matrículas no ensino fundamental[2020]             float64  8059760
# IDH[2010]                                           float64  8059760
# balanco_financeiro- R$ (×1000) [2017]               float64  8059760
# Rendimento mensal domiciliar per capita - R$ [2...  float64  8059760
# Total de veículos - veículos [2021]                 float64  8059760
#
#                                                     % missing   unique  \
# contrato_id                                          0.000000    14756
# dt_ref_portfolio                                     0.000000      838
# safra                                                0.000000       18
# nr_documento                                         0.000000    14265
# status_contrato                                      0.000000        6
# dt_contrato                                          0.000000      526
# dt_desembolso                                        0.000000      355
# dt_vencimento                                        0.000000      736
# dt_wo                                                0.000000      736
# prazo                                                0.000000        8
# vlr_desembolsado                                     0.000000     8784
# vlr_tarifa                                           0.000000      772
# juros_mes                                            0.000000       28
# juros_diario                                         0.000000       28
# perc_retencao                                        0.000000     2301
# vlr_pgto_realizado                                   0.000000   111430
# vlr_pgto_esperado                                    0.000000    12643
# vlr_saldo_devedor                                    0.000000  2879232
# vlr_saldo_devedor_esperado                           0.000000  3050274
# dsp                                                  0.000000      792
# dspp                                                 0.000000      834
# flag_transacao                                       0.000000        2
# data_acao                                           97.637094      594
# acao                                                97.637094        5
# tp_acao1                                            97.637094        1
# st_acao1                                            97.637094        4
# tp_acao2                                            97.637094        2
# st_acao2                                            97.637094        4
# dt_transacao                                        70.186029      546
# qtd_transacoes                                      70.186029      608
# vlr_tpv                                             70.186029   367503
# tipo_empresa                                         0.000000        3
# cidade                                               0.000000     1501
# estado                                               0.000000       28
# subsegmento                                          0.000000       16
# segmento                                             0.000000        9
# População estimada - pessoas [2021]                  0.015457       27
# Densidade demográfica [2010]                         0.015457       27
# Matrículas no ensino fundamental[2020]              0.015457       27
# IDH[2010]                                            0.015457       26
# balanco_financeiro- R$ (×1000) [2017]                0.015457       27
# Rendimento mensal domiciliar per capita - R$ [2...   0.015457       27
# Total de veículos - veículos [2021]                  0.015457       27
#
#                                                     duplicated
# contrato_id                                            8046250
# dt_ref_portfolio                                       8060168
# safra                                                  8060988
# nr_documento                                           8046741
# status_contrato                                        8061000
# dt_contrato                                            8060480
# dt_desembolso                                          8060651
# dt_vencimento                                          8060270
# dt_wo                                                  8060270
# prazo                                                  8060998
# vlr_desembolsado                                       8052222
# vlr_tarifa                                             8060234
# juros_mes                                              8060978
# juros_diario                                           8060978
# perc_retencao                                          8058705
# vlr_pgto_realizado                                     7949576
# vlr_pgto_esperado                                      8048363
# vlr_saldo_devedor                                      5181774
# vlr_saldo_devedor_esperado                             5010732
# dsp                                                    8060214
# dspp                                                   8060172
# flag_transacao                                         8061004
# data_acao                                               189880
# acao                                                    190469
# tp_acao1                                                190473
# st_acao1                                                190470
# tp_acao2                                                190472
# st_acao2                                                190470
# dt_transacao                                           2402760
# qtd_transacoes                                         2402698
# vlr_tpv                                                2035803
# tipo_empresa                                           8061003
# cidade                                                 8059505
# estado                                                 8060978
# subsegmento                                            8060990
# segmento                                               8060997
# População estimada - pessoas [2021]                    8059733
# Densidade demográfica [2010]                           8059733
# Matrículas no ensino fundamental[2020]                8059733
# IDH[2010]                                              8059734
# balanco_financeiro- R$ (×1000) [2017]                  8059733
# Rendimento mensal domiciliar per capita - R$ [2...     8059733
# Total de veículos - veículos [2021]                    8059733

# %% [markdown]
# ### <font color=green>  4.1 - MÉTRICAS (BASE LINE)</font>

# %% [markdown]
# #### <font color=green>  4.1.1 - Curva de sazionalidade por data de transacao (portifolio tpv)</font>

# %%
# Curva de sazionalidade por data de transacao (portifolio tpv)
fig,ax = plt.subplots(figsize=(20,8))
sns.lineplot(x= df['dt_transacao'] , y=df['vlr_tpv'],
                data=df , ax=ax, color="#4CB391" )

ax.axhline(df['vlr_tpv'].mean(), color='green')
ax.set_title('Curva de sazionalidade por data de transacao (portifolio tpv)')
plt.show()
print('Média de vlr_tpv {:.2f}'.format(df['vlr_tpv'].mean()))
# Out:
# Média de vlr_tpv 926.31

# %% [markdown]
# Análise de tempo:
#
# Olhando para o curva de sazonalidade percebe-se que 2020 foi afetado diretamente pela pandemia e 2021 ainda não reflete o cenário futuro que a recomendação desse estudo irá se deparar.
#
# Portanto o espaço temporal escolhido foi dos últimos 6 meses apartir da última data de referencia do contrato, porque representa o mais próximo da realidade futura e ainda comtlempla o pico nov-jan e o vale fev-abr, segundo a curva de sazonalidade.

# %%
# Filtrando o dataset pela análise de tempo estabelecida acima
df = df[(df['dt_ref_portfolio']>'2021-10-19') & (df['dt_ref_portfolio']<'2022-04-19')]

# Excluídas as colunas abaixo por que a base de tpv nao comtempla esse período
df.drop(columns=['dt_transacao','qtd_transacoes','vlr_tpv'] , inplace=True)

# Eliminando as linha que tinham inconsitencia no preenchimento da sigla dos estados (ND, representava 0,01%).
df = df[df['estado']!='ND']

# alinhando por data de referencia do portifolio (para garantir!)
df.sort_values(by='dt_ref_portfolio' ,ascending=True, inplace=True)

# Resetando o index
df.reset_index(drop=True, inplace=True)
# Out:
#                                                       types    count  \
# contrato_id                                          object  2670474
# dt_ref_portfolio                                     object  2670474
# safra                                                object  2670474
# nr_documento                                         object  2670474
# status_contrato                                      object  2670474
# dt_contrato                                          object  2670474
# dt_desembolso                                        object  2670474
# dt_vencimento                                        object  2670474
# dt_wo                                                object  2670474
# prazo                                               float64  2670474
# vlr_desembolsado                                    float64  2670474
# vlr_tarifa                                          float64  2670474
# juros_mes                                           float64  2670474
# juros_diario                                        float64  2670474
# perc_retencao                                       float64  2670474
# vlr_pgto_realizado                                  float64  2670474
# vlr_pgto_esperado                                   float64  2670474
# vlr_saldo_devedor                                   float64  2670474
# vlr_saldo_devedor_esperado                          float64  2670474
# dsp                                                   int64  2670474
# dspp                                                  int64  2670474
# flag_transacao                                        int64  2670474
# data_acao                                            object    54680
# acao                                                 object    54680
# tp_acao1                                             object    54680
# st_acao1                                             object    54680
# tp_acao2                                             object    54680
# st_acao2                                             object    54680
# tipo_empresa                                         object  2670474
# cidade                                               object  2670474
# estado                                               object  2670474
# subsegmento                                          object  2670474
# segmento                                             object  2670474
# População estimada - pessoas [2021]                 float64  2670474
# Densidade demográfica [2010]                        float64  2670474
# Matrículas no ensino fundamental[2020]             float64  2670474
# IDH[2010]                                           float64  2670474
# balanco_financeiro- R$ (×1000) [2017]               float64  2670474
# Rendimento mensal domiciliar per capita - R$ [2...  float64  2670474
# Total de veículos - veículos [2021]                 float64  2670474
#
#                                                     % missing   unique  \
# contrato_id                                          0.000000    14754
# dt_ref_portfolio                                     0.000000      181
# safra                                                0.000000       18
# nr_documento                                         0.000000    14263
# status_contrato                                      0.000000        3
# dt_contrato                                          0.000000      525
# dt_desembolso                                        0.000000      355
# dt_vencimento                                        0.000000      733
# dt_wo                                                0.000000      733
# prazo                                                0.000000        8
# vlr_desembolsado                                     0.000000     8782
# vlr_tarifa                                           0.000000      770
# juros_mes                                            0.000000       28
# juros_diario                                         0.000000       28
# perc_retencao                                        0.000000     1980
# vlr_pgto_realizado                                   0.000000    61101
# vlr_pgto_esperado                                    0.000000    11593
# vlr_saldo_devedor                                    0.000000  1162859
# vlr_saldo_devedor_esperado                           0.000000   762677
# dsp                                                  0.000000      792
# dspp                                                 0.000000      834
# flag_transacao                                       0.000000        2
# data_acao                                           97.952423      130
# acao                                                97.952423        5
# tp_acao1                                            97.952423        1
# st_acao1                                            97.952423        4
# tp_acao2                                            97.952423        2
# st_acao2                                            97.952423        4
# tipo_empresa                                         0.000000        3
# cidade                                               0.000000     1500
# estado                                               0.000000       27
# subsegmento                                          0.000000       16
# segmento                                             0.000000        9
# População estimada - pessoas [2021]                  0.000000       27
# Densidade demográfica [2010]                         0.000000       27
# Matrículas no ensino fundamental[2020]              0.000000       27
# IDH[2010]                                            0.000000       26
# balanco_financeiro- R$ (×1000) [2017]                0.000000       27
# Rendimento mensal domiciliar per capita - R$ [2...   0.000000       27
# Total de veículos - veículos [2021]                  0.000000       27
#
#                                                     duplicated
# contrato_id                                            2655720
# dt_ref_portfolio                                       2670293
# safra                                                  2670456
# nr_documento                                           2656211
# status_contrato                                        2670471
# dt_contrato                                            2669949
# dt_desembolso                                          2670119
# dt_vencimento                                          2669741
# dt_wo                                                  2669741
# prazo                                                  2670466
# vlr_desembolsado                                       2661692
# vlr_tarifa                                             2669704
# juros_mes                                              2670446
# juros_diario                                           2670446
# perc_retencao                                          2668494
# vlr_pgto_realizado                                     2609373
# vlr_pgto_esperado                                      2658881
# vlr_saldo_devedor                                      1507615
# vlr_saldo_devedor_esperado                             1907797
# dsp                                                    2669682
# dspp                                                   2669640
# flag_transacao                                         2670472
# data_acao                                                54550
# acao                                                     54675
# tp_acao1                                                 54679
# st_acao1                                                 54676
# tp_acao2                                                 54678
# st_acao2                                                 54676
# tipo_empresa                                           2670471
# cidade                                                 2668974
# estado                                                 2670447
# subsegmento                                            2670458
# segmento                                               2670465
# População estimada - pessoas [2021]                    2670447
# Densidade demográfica [2010]                           2670447
# Matrículas no ensino fundamental[2020]                2670447
# IDH[2010]                                              2670448
# balanco_financeiro- R$ (×1000) [2017]                  2670447
# Rendimento mensal domiciliar per capita - R$ [2...     2670447
# Total de veículos - veículos [2021]                    2670447

# %% [markdown]
# #### <font color=green>  4.1.2 - Agrupamentos e filtros da base única</font>

# %%
# Salvando em novo objeto para manter o histórico e viabilizar um row back
df1 = df

# Filtrando somente linhas com acionamentos
df1 = df1[(df1['acao'].notna())]

# # Filtrando somentes as colunas de interesse
# df1 = df1[['contrato_id','dt_ref_portfolio','dsp','dspp','data_acao','acao','tp_acao1','st_acao1','tp_acao2','st_acao2']]

# Renomeando as colunas 
df1.rename(columns={'tp_acao1':'canal_email','tp_acao2':'canal_hsm',
                   'st_acao1':'st_email','st_acao2':'st_hsm'}, inplace=True)

# # Atribuindo valor as colunas de acao para contagem no agrupamento
# df1['canal_email'] = 1
# df1['canal_hsm'] = 1

# # Fazendo a One hot encoding 
# df1 = pd.get_dummies(df1, columns= ['st_acao1','st_acao2'])

# Resetando o index
df1.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### <font color=green>  4.1.3 - Gráfico Geral de engajamento por canal</font>

# %%
# invocando a função varqual (ver seção functions acima)
order = ['NAO ENTREGUE','ENTREGUE','LIDO', 'RESPONDIDO' ]
varqual(df1, 'st_email', order, 'Engajamento canal Email por status')
# Out:
# st_email
# ********************************************************************************
#
# NAO ENTREGUE    47.46
# ENTREGUE        34.12
# LIDO            17.52
# RESPONDIDO       0.90
# Name: st_email, dtype: float64

# %%
# invocando a função varqual (ver seção functions acima)
order = ['NAO ENTREGUE','ENTREGUE','LIDO', 'RESPONDIDO' ]
varqual(df1, 'st_hsm', order, 'Engajamento canal HSM por status')
# Out:
# st_hsm
# ********************************************************************************
#
# NAO ENTREGUE    47.38
# ENTREGUE        34.13
# LIDO            17.78
# RESPONDIDO       0.71
# Name: st_hsm, dtype: float64

# %% [markdown]
# #### <font color=green>  4.1.4 - Gráfico Geral de engajamento por canal e tipo de ação</font>

# %%
# invocando a função qual_qual (ver seção functions acima)
# Esse gráfico mostra o % de cada etapa de engajamento por campanha com o canal de comunicação hsm
qual_qual(df1, 'acao', 'st_hsm')

# %%
# invocando a função qual_qual (ver seção functions acima)
# Esse gráfico mostra o % de cada etapa de engajamento por campanha com o canal de comunicação email
qual_qual(df1, 'acao', 'st_email')

# %% [markdown]
# #### <font color=green>  4.1.5 - rankinq geral de dsp/dspp por segmento/tipo de empresa</font>

# %%
# Agrupamento por tipo segmento a média dsp/dspp e alinhado por dspp
(df.groupby(by=['segmento'])['dsp', 'dspp'].mean()).sort_values(by='dspp', ascending=False)
# Out:
#                                 dsp       dspp
# segmento
# Viagens e entretenimento  38.288729  89.547680
# Serviços                  31.903066  74.615402
# Varejo                    30.352090  70.863074
# Bens duráveis             27.663237  69.474175
# Alimentação               27.208113  69.160389
# Serviços recorrentes      22.334843  63.969190
# Posto                     30.246047  59.790373
# Outros                    21.015096  57.843903
# Supermercado/Farmácia     23.132266  52.606350

# %%
# Agrupamento por tipo retornando a média dsp/dspp e alinhado por dspp
(df.groupby(by='tipo_empresa')['dsp', 'dspp'].mean()).sort_values(by='dspp', ascending=False)
# Out:
#                     dsp       dspp
# tipo_empresa
# MEI           33.372753  79.008629
# PF            33.580616  75.778963
# PJ            24.009803  61.150676

# %% [markdown]
# #### <font color=green>  4.1.6 - Criação da janelas de efetividade das ações</font>

# %%
df['efetividade'] = ''

for i in range(len(df['contrato_id'])):
    if ((df['st_acao1'][i] == 'LIDO') | (df['st_acao2'][i] == 'LIDO')) | ((df['st_acao1'][i] == 'RESPONDIDO') | (df['st_acao2'][i] == 'RESPONDIDO')):
        df['efetividade'] = 1
    else:        
        df['efetividade'] = 0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3971/446353737.py in <module>
#       5         df['efetividade'] = 1
#       6     else:
# ----> 7         df['efetividade'] = 0
#       8
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4508         if is_list_like(value):
#    4509             com.require_length_match(value, self.index)
# -> 4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#    4512     @property
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     512         if index is None:
#     513             raise ValueError("index must be specified when data is not list-like")
# --> 514         data = construct_1d_arraylike_from_scalar(data, len(index), dtype)
#     515         return data
#     516
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1922
#    1923         subarr = np.empty(length, dtype=dtype)
# -> 1924         subarr.fill(value)
#    1925
#    1926     return subarr
#
# KeyboardInterrupt:

# %%
engajamento = list(['LIDO', 'RESPONDIDO'])
df['efetividade'] = ''

for i in range(len(df['contrato_id'])):
    if (df['acao'][i] == 'campanhaobservacao') & (df['st_acao1'][i].isin(engajamento) | df['st_acao2'][i].isin(engajamento)):
        if df['vlr_pgto_realizado'][i:i+5].sum() != 0:
            df['efetividade'][i] = 1
        else:     
            df['efetividade'][i] = 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3971/1014494908.py in <module>
#       3
#       4 for i in range(len(df['contrato_id'])):
# ----> 5     if (df['acao'][i] == 'campanhaobservacao') & ((df['st_acao1'][i]).isin(engajamento) | (df['st_acao2'][i]).isin(engajamento)):
#       6         if df['vlr_pgto_realizado'][i:i+5].sum() != 0:
#       7             df['efetividade'][i] = 1
#
# AttributeError: 'float' object has no attribute 'isin'

# %%
df['vlr_pgto_realizado'][0:5].sum()
# Out:
# 56.33

# %%
df['vlr_pgto_realizado'][10:16]
# Out:
# 12      0.00
# 14      0.00
# 15      0.00
# 100     0.00
# 101     0.00
# 102    56.33
# Name: vlr_pgto_realizado, dtype: float64

# %%
df = df[df['contrato_id']=='e4753f517397dec57e638d49b982fc96']
df['dt_ref_portfolio'] = pd.to_datetime(df['dt_ref_portfolio'])
df.sort_values(by='dt_ref_portfolio' ,ascending=True, inplace=True)
pd.set_option('display.max_rows', None)
df[['contrato_id', 'dt_ref_portfolio','vlr_pgto_realizado',
       'vlr_saldo_devedor',
       'dsp', 'dspp', 'data_acao', 'acao']]
# Out:
#                               contrato_id dt_ref_portfolio  \
# 580330   e4753f517397dec57e638d49b982fc96       2020-03-04
# 2318303  e4753f517397dec57e638d49b982fc96       2020-03-05
# 1923029  e4753f517397dec57e638d49b982fc96       2020-03-06
# 115711   e4753f517397dec57e638d49b982fc96       2020-03-07
# 6841631  e4753f517397dec57e638d49b982fc96       2020-03-08
# 3751397  e4753f517397dec57e638d49b982fc96       2020-03-09
# 2232849  e4753f517397dec57e638d49b982fc96       2020-03-10
# 3040260  e4753f517397dec57e638d49b982fc96       2020-03-11
# 6041853  e4753f517397dec57e638d49b982fc96       2020-03-12
# 7912624  e4753f517397dec57e638d49b982fc96       2020-03-13
# 8060487  e4753f517397dec57e638d49b982fc96       2020-03-14
# 200740   e4753f517397dec57e638d49b982fc96       2020-03-15
# 7902021  e4753f517397dec57e638d49b982fc96       2020-03-16
# 1151271  e4753f517397dec57e638d49b982fc96       2020-03-17
# 1296612  e4753f517397dec57e638d49b982fc96       2020-03-18
# 6270203  e4753f517397dec57e638d49b982fc96       2020-03-19
# 693467   e4753f517397dec57e638d49b982fc96       2020-03-20
# 3570028  e4753f517397dec57e638d49b982fc96       2020-03-21
# 7510083  e4753f517397dec57e638d49b982fc96       2020-03-22
# 121878   e4753f517397dec57e638d49b982fc96       2020-03-23
# 7506771  e4753f517397dec57e638d49b982fc96       2020-03-24
# 7911354  e4753f517397dec57e638d49b982fc96       2020-03-25
# 1708258  e4753f517397dec57e638d49b982fc96       2020-03-26
# 2371824  e4753f517397dec57e638d49b982fc96       2020-03-27
# 6969313  e4753f517397dec57e638d49b982fc96       2020-03-28
# 4934471  e4753f517397dec57e638d49b982fc96       2020-03-29
# 2435214  e4753f517397dec57e638d49b982fc96       2020-03-30
# 4118678  e4753f517397dec57e638d49b982fc96       2020-03-31
# 5903398  e4753f517397dec57e638d49b982fc96       2020-04-01
# 887508   e4753f517397dec57e638d49b982fc96       2020-04-02
# 161838   e4753f517397dec57e638d49b982fc96       2020-04-03
# 1670699  e4753f517397dec57e638d49b982fc96       2020-04-04
# 6925984  e4753f517397dec57e638d49b982fc96       2020-04-05
# 1816793  e4753f517397dec57e638d49b982fc96       2020-04-06
# 4582874  e4753f517397dec57e638d49b982fc96       2020-04-07
# 7700652  e4753f517397dec57e638d49b982fc96       2020-04-08
# 152724   e4753f517397dec57e638d49b982fc96       2020-04-09
# 7870980  e4753f517397dec57e638d49b982fc96       2020-04-10
# 3860470  e4753f517397dec57e638d49b982fc96       2020-04-11
# 4940005  e4753f517397dec57e638d49b982fc96       2020-04-12
# 407401   e4753f517397dec57e638d49b982fc96       2020-04-13
# 7865004  e4753f517397dec57e638d49b982fc96       2020-04-14
# 6935532  e4753f517397dec57e638d49b982fc96       2020-04-15
# 2317838  e4753f517397dec57e638d49b982fc96       2020-04-16
# 7910764  e4753f517397dec57e638d49b982fc96       2020-04-17
# 1845533  e4753f517397dec57e638d49b982fc96       2020-04-18
# 616970   e4753f517397dec57e638d49b982fc96       2020-04-19
# 2319664  e4753f517397dec57e638d49b982fc96       2020-04-20
# 2367133  e4753f517397dec57e638d49b982fc96       2020-04-21
# 2433005  e4753f517397dec57e638d49b982fc96       2020-04-22
# 4220032  e4753f517397dec57e638d49b982fc96       2020-04-23
# 6837767  e4753f517397dec57e638d49b982fc96       2020-04-24
# 6838088  e4753f517397dec57e638d49b982fc96       2020-04-25
# 4804198  e4753f517397dec57e638d49b982fc96       2020-04-26
# 7585503  e4753f517397dec57e638d49b982fc96       2020-04-27
# 626054   e4753f517397dec57e638d49b982fc96       2020-04-28
# 3504982  e4753f517397dec57e638d49b982fc96       2020-04-29
# 2562062  e4753f517397dec57e638d49b982fc96       2020-04-30
# 2317803  e4753f517397dec57e638d49b982fc96       2020-05-01
# 1470593  e4753f517397dec57e638d49b982fc96       2020-05-02
# 1176153  e4753f517397dec57e638d49b982fc96       2020-05-03
# 6163041  e4753f517397dec57e638d49b982fc96       2020-05-04
# 1254650  e4753f517397dec57e638d49b982fc96       2020-05-05
# 2436650  e4753f517397dec57e638d49b982fc96       2020-05-06
# 6157723  e4753f517397dec57e638d49b982fc96       2020-05-07
# 1704699  e4753f517397dec57e638d49b982fc96       2020-05-08
# 7904135  e4753f517397dec57e638d49b982fc96       2020-05-09
# 7883770  e4753f517397dec57e638d49b982fc96       2020-05-10
# 4425671  e4753f517397dec57e638d49b982fc96       2020-05-11
# 5323185  e4753f517397dec57e638d49b982fc96       2020-05-12
# 2131569  e4753f517397dec57e638d49b982fc96       2020-05-13
# 4480771  e4753f517397dec57e638d49b982fc96       2020-05-14
# 6833020  e4753f517397dec57e638d49b982fc96       2020-05-15
# 4602083  e4753f517397dec57e638d49b982fc96       2020-05-16
# 2233255  e4753f517397dec57e638d49b982fc96       2020-05-17
# 409003   e4753f517397dec57e638d49b982fc96       2020-05-18
# 7125403  e4753f517397dec57e638d49b982fc96       2020-05-19
# 7886435  e4753f517397dec57e638d49b982fc96       2020-05-20
# 2823562  e4753f517397dec57e638d49b982fc96       2020-05-21
# 7508316  e4753f517397dec57e638d49b982fc96       2020-05-22
# 6369175  e4753f517397dec57e638d49b982fc96       2020-05-23
# 1909758  e4753f517397dec57e638d49b982fc96       2020-05-24
# 1913579  e4753f517397dec57e638d49b982fc96       2020-05-25
# 2437956  e4753f517397dec57e638d49b982fc96       2020-05-26
# 7615898  e4753f517397dec57e638d49b982fc96       2020-05-27
# 5590950  e4753f517397dec57e638d49b982fc96       2020-05-28
# 6708883  e4753f517397dec57e638d49b982fc96       2020-05-29
# 6168301  e4753f517397dec57e638d49b982fc96       2020-05-30
# 7865807  e4753f517397dec57e638d49b982fc96       2020-05-31
# 7616161  e4753f517397dec57e638d49b982fc96       2020-06-01
# 7508693  e4753f517397dec57e638d49b982fc96       2020-06-02
# 614368   e4753f517397dec57e638d49b982fc96       2020-06-03
# 3827271  e4753f517397dec57e638d49b982fc96       2020-06-04
# 3760793  e4753f517397dec57e638d49b982fc96       2020-06-05
# 6045339  e4753f517397dec57e638d49b982fc96       2020-06-06
# 1154819  e4753f517397dec57e638d49b982fc96       2020-06-07
# 5423984  e4753f517397dec57e638d49b982fc96       2020-06-08
# 2049550  e4753f517397dec57e638d49b982fc96       2020-06-09
# 7506198  e4753f517397dec57e638d49b982fc96       2020-06-10
# 5023302  e4753f517397dec57e638d49b982fc96       2020-06-11
# 1180277  e4753f517397dec57e638d49b982fc96       2020-06-12
# 3724268  e4753f517397dec57e638d49b982fc96       2020-06-13
# 7884002  e4753f517397dec57e638d49b982fc96       2020-06-14
# 7953830  e4753f517397dec57e638d49b982fc96       2020-06-15
# 6925679  e4753f517397dec57e638d49b982fc96       2020-06-16
# 7952541  e4753f517397dec57e638d49b982fc96       2020-06-17
# 5903559  e4753f517397dec57e638d49b982fc96       2020-06-18
# 881121   e4753f517397dec57e638d49b982fc96       2020-06-19
# 2316464  e4753f517397dec57e638d49b982fc96       2020-06-20
# 4272403  e4753f517397dec57e638d49b982fc96       2020-06-21
# 5904286  e4753f517397dec57e638d49b982fc96       2020-06-22
# 6158015  e4753f517397dec57e638d49b982fc96       2020-06-23
# 6709230  e4753f517397dec57e638d49b982fc96       2020-06-24
# 7738496  e4753f517397dec57e638d49b982fc96       2020-06-25
# 1817313  e4753f517397dec57e638d49b982fc96       2020-06-26
# 1259851  e4753f517397dec57e638d49b982fc96       2020-06-27
# 3466961  e4753f517397dec57e638d49b982fc96       2020-06-28
# 6714301  e4753f517397dec57e638d49b982fc96       2020-06-29
# 6612764  e4753f517397dec57e638d49b982fc96       2020-06-30
# 1715619  e4753f517397dec57e638d49b982fc96       2020-07-01
# 7883764  e4753f517397dec57e638d49b982fc96       2020-07-02
# 1148484  e4753f517397dec57e638d49b982fc96       2020-07-03
# 8060786  e4753f517397dec57e638d49b982fc96       2020-07-04
# 1642686  e4753f517397dec57e638d49b982fc96       2020-07-05
# 1154686  e4753f517397dec57e638d49b982fc96       2020-07-06
# 4939984  e4753f517397dec57e638d49b982fc96       2020-07-07
# 7912650  e4753f517397dec57e638d49b982fc96       2020-07-08
# 1299531  e4753f517397dec57e638d49b982fc96       2020-07-09
# 7617138  e4753f517397dec57e638d49b982fc96       2020-07-10
# 2978972  e4753f517397dec57e638d49b982fc96       2020-07-11
# 1638328  e4753f517397dec57e638d49b982fc96       2020-07-12
# 181884   e4753f517397dec57e638d49b982fc96       2020-07-13
# 529147   e4753f517397dec57e638d49b982fc96       2020-07-14
# 881342   e4753f517397dec57e638d49b982fc96       2020-07-15
# 2439376  e4753f517397dec57e638d49b982fc96       2020-07-16
# 1699449  e4753f517397dec57e638d49b982fc96       2020-07-17
# 283093   e4753f517397dec57e638d49b982fc96       2020-07-18
# 5033699  e4753f517397dec57e638d49b982fc96       2020-07-19
# 6037528  e4753f517397dec57e638d49b982fc96       2020-07-20
# 4386812  e4753f517397dec57e638d49b982fc96       2020-07-21
# 3827275  e4753f517397dec57e638d49b982fc96       2020-07-22
# 1420879  e4753f517397dec57e638d49b982fc96       2020-07-23
# 7905242  e4753f517397dec57e638d49b982fc96       2020-07-24
# 1819969  e4753f517397dec57e638d49b982fc96       2020-07-25
# 6709120  e4753f517397dec57e638d49b982fc96       2020-07-26
# 2004727  e4753f517397dec57e638d49b982fc96       2020-07-27
# 6707050  e4753f517397dec57e638d49b982fc96       2020-07-28
# 530906   e4753f517397dec57e638d49b982fc96       2020-07-29
# 2213226  e4753f517397dec57e638d49b982fc96       2020-07-30
# 1424220  e4753f517397dec57e638d49b982fc96       2020-07-31
# 7889427  e4753f517397dec57e638d49b982fc96       2020-08-01
# 1424125  e4753f517397dec57e638d49b982fc96       2020-08-02
# 2776296  e4753f517397dec57e638d49b982fc96       2020-08-03
# 8059256  e4753f517397dec57e638d49b982fc96       2020-08-04
# 235544   e4753f517397dec57e638d49b982fc96       2020-08-05
# 3723293  e4753f517397dec57e638d49b982fc96       2020-08-06
# 7663540  e4753f517397dec57e638d49b982fc96       2020-08-07
# 2410515  e4753f517397dec57e638d49b982fc96       2020-08-08
# 699822   e4753f517397dec57e638d49b982fc96       2020-08-09
# 7661252  e4753f517397dec57e638d49b982fc96       2020-08-10
# 534636   e4753f517397dec57e638d49b982fc96       2020-08-11
# 811597   e4753f517397dec57e638d49b982fc96       2020-08-12
# 2408240  e4753f517397dec57e638d49b982fc96       2020-08-13
# 5531704  e4753f517397dec57e638d49b982fc96       2020-08-14
# 1299683  e4753f517397dec57e638d49b982fc96       2020-08-15
# 2410826  e4753f517397dec57e638d49b982fc96       2020-08-16
# 7176026  e4753f517397dec57e638d49b982fc96       2020-08-17
# 7762738  e4753f517397dec57e638d49b982fc96       2020-08-18
# 2993536  e4753f517397dec57e638d49b982fc96       2020-08-19
# 5082391  e4753f517397dec57e638d49b982fc96       2020-08-20
# 4603379  e4753f517397dec57e638d49b982fc96       2020-08-21
# 1259746  e4753f517397dec57e638d49b982fc96       2020-08-22
# 122457   e4753f517397dec57e638d49b982fc96       2020-08-23
# 7958012  e4753f517397dec57e638d49b982fc96       2020-08-24
# 7083992  e4753f517397dec57e638d49b982fc96       2020-08-25
# 3757373  e4753f517397dec57e638d49b982fc96       2020-08-26
# 122177   e4753f517397dec57e638d49b982fc96       2020-08-27
# 1670574  e4753f517397dec57e638d49b982fc96       2020-08-28
# 8060430  e4753f517397dec57e638d49b982fc96       2020-08-29
# 542362   e4753f517397dec57e638d49b982fc96       2020-08-30
# 6040866  e4753f517397dec57e638d49b982fc96       2020-08-31
# 2336554  e4753f517397dec57e638d49b982fc96       2020-09-01
# 282840   e4753f517397dec57e638d49b982fc96       2020-09-02
# 6969502  e4753f517397dec57e638d49b982fc96       2020-09-03
# 5530776  e4753f517397dec57e638d49b982fc96       2020-09-04
# 6925262  e4753f517397dec57e638d49b982fc96       2020-09-05
# 6036875  e4753f517397dec57e638d49b982fc96       2020-09-06
# 4272449  e4753f517397dec57e638d49b982fc96       2020-09-07
# 8034173  e4753f517397dec57e638d49b982fc96       2020-09-08
# 5080657  e4753f517397dec57e638d49b982fc96       2020-09-09
# 5587318  e4753f517397dec57e638d49b982fc96       2020-09-10
# 2979760  e4753f517397dec57e638d49b982fc96       2020-09-11
# 7861402  e4753f517397dec57e638d49b982fc96       2020-09-12
# 1254517  e4753f517397dec57e638d49b982fc96       2020-09-13
# 3828819  e4753f517397dec57e638d49b982fc96       2020-09-14
# 887144   e4753f517397dec57e638d49b982fc96       2020-09-15
# 7873469  e4753f517397dec57e638d49b982fc96       2020-09-16
# 2319463  e4753f517397dec57e638d49b982fc96       2020-09-17
# 408954   e4753f517397dec57e638d49b982fc96       2020-09-18
# 1517743  e4753f517397dec57e638d49b982fc96       2020-09-19
# 201238   e4753f517397dec57e638d49b982fc96       2020-09-20
# 1814184  e4753f517397dec57e638d49b982fc96       2020-09-21
# 591800   e4753f517397dec57e638d49b982fc96       2020-09-22
# 1031016  e4753f517397dec57e638d49b982fc96       2020-09-23
# 7868378  e4753f517397dec57e638d49b982fc96       2020-09-24
# 280518   e4753f517397dec57e638d49b982fc96       2020-09-25
# 2049552  e4753f517397dec57e638d49b982fc96       2020-09-26
# 2370407  e4753f517397dec57e638d49b982fc96       2020-09-27
# 183205   e4753f517397dec57e638d49b982fc96       2020-09-28
# 3467199  e4753f517397dec57e638d49b982fc96       2020-09-29
# 7865582  e4753f517397dec57e638d49b982fc96       2020-09-30
# 3548183  e4753f517397dec57e638d49b982fc96       2020-10-01
# 7069266  e4753f517397dec57e638d49b982fc96       2020-10-02
# 2432941  e4753f517397dec57e638d49b982fc96       2020-10-03
# 1663070  e4753f517397dec57e638d49b982fc96       2020-10-04
# 3330842  e4753f517397dec57e638d49b982fc96       2020-10-05
# 2004724  e4753f517397dec57e638d49b982fc96       2020-10-06
# 7068940  e4753f517397dec57e638d49b982fc96       2020-10-07
# 106803   e4753f517397dec57e638d49b982fc96       2020-10-08
# 2317576  e4753f517397dec57e638d49b982fc96       2020-10-09
# 3243034  e4753f517397dec57e638d49b982fc96       2020-10-10
# 5903245  e4753f517397dec57e638d49b982fc96       2020-10-11
# 587769   e4753f517397dec57e638d49b982fc96       2020-10-12
# 4278699  e4753f517397dec57e638d49b982fc96       2020-10-13
# 4651262  e4753f517397dec57e638d49b982fc96       2020-10-14
# 3751076  e4753f517397dec57e638d49b982fc96       2020-10-15
# 1297365  e4753f517397dec57e638d49b982fc96       2020-10-16
# 8061005  e4753f517397dec57e638d49b982fc96       2020-10-17
# 1024492  e4753f517397dec57e638d49b982fc96       2020-10-18
# 4583050  e4753f517397dec57e638d49b982fc96       2020-10-19
# 1019524  e4753f517397dec57e638d49b982fc96       2020-10-20
# 7871645  e4753f517397dec57e638d49b982fc96       2020-10-21
# 2049639  e4753f517397dec57e638d49b982fc96       2020-10-22
# 583712   e4753f517397dec57e638d49b982fc96       2020-10-23
# 7617059  e4753f517397dec57e638d49b982fc96       2020-10-24
# 805940   e4753f517397dec57e638d49b982fc96       2020-10-25
# 1024859  e4753f517397dec57e638d49b982fc96       2020-10-26
# 5576576  e4753f517397dec57e638d49b982fc96       2020-10-27
# 1813595  e4753f517397dec57e638d49b982fc96       2020-10-28
# 3827495  e4753f517397dec57e638d49b982fc96       2020-10-29
# 2437860  e4753f517397dec57e638d49b982fc96       2020-10-30
# 1019667  e4753f517397dec57e638d49b982fc96       2020-10-31
# 4600417  e4753f517397dec57e638d49b982fc96       2020-11-01
# 173417   e4753f517397dec57e638d49b982fc96       2020-11-02
# 7738479  e4753f517397dec57e638d49b982fc96       2020-11-03
# 7873942  e4753f517397dec57e638d49b982fc96       2020-11-04
# 4934133  e4753f517397dec57e638d49b982fc96       2020-11-05
# 3505151  e4753f517397dec57e638d49b982fc96       2020-11-06
# 4480953  e4753f517397dec57e638d49b982fc96       2020-11-07
# 6201384  e4753f517397dec57e638d49b982fc96       2020-11-08
# 2319644  e4753f517397dec57e638d49b982fc96       2020-11-09
# 6935980  e4753f517397dec57e638d49b982fc96       2020-11-10
# 2211707  e4753f517397dec57e638d49b982fc96       2020-11-11
# 2978858  e4753f517397dec57e638d49b982fc96       2020-11-12
# 5587370  e4753f517397dec57e638d49b982fc96       2020-11-13
# 1148442  e4753f517397dec57e638d49b982fc96       2020-11-14
# 7911297  e4753f517397dec57e638d49b982fc96       2020-11-15
# 7694900  e4753f517397dec57e638d49b982fc96       2020-11-16
# 6714191  e4753f517397dec57e638d49b982fc96       2020-11-17
# 8060992  e4753f517397dec57e638d49b982fc96       2020-11-18
# 1637608  e4753f517397dec57e638d49b982fc96       2020-11-19
# 6924002  e4753f517397dec57e638d49b982fc96       2020-11-20
# 3751091  e4753f517397dec57e638d49b982fc96       2020-11-21
# 2213193  e4753f517397dec57e638d49b982fc96       2020-11-22
# 2979018  e4753f517397dec57e638d49b982fc96       2020-11-23
# 3566199  e4753f517397dec57e638d49b982fc96       2020-11-24
# 3246646  e4753f517397dec57e638d49b982fc96       2020-11-25
# 5904489  e4753f517397dec57e638d49b982fc96       2020-11-26
# 583599   e4753f517397dec57e638d49b982fc96       2020-11-27
# 1913260  e4753f517397dec57e638d49b982fc96       2020-11-28
# 6454093  e4753f517397dec57e638d49b982fc96       2020-11-29
# 5904113  e4753f517397dec57e638d49b982fc96       2020-11-30
# 7904523  e4753f517397dec57e638d49b982fc96       2020-12-01
# 6838254  e4753f517397dec57e638d49b982fc96       2020-12-02
# 5527105  e4753f517397dec57e638d49b982fc96       2020-12-03
# 8060283  e4753f517397dec57e638d49b982fc96       2020-12-04
# 1925680  e4753f517397dec57e638d49b982fc96       2020-12-05
# 6045181  e4753f517397dec57e638d49b982fc96       2020-12-06
# 6838364  e4753f517397dec57e638d49b982fc96       2020-12-07
# 3546418  e4753f517397dec57e638d49b982fc96       2020-12-08
# 1471218  e4753f517397dec57e638d49b982fc96       2020-12-09
# 7952590  e4753f517397dec57e638d49b982fc96       2020-12-10
# 7175886  e4753f517397dec57e638d49b982fc96       2020-12-11
# 7508254  e4753f517397dec57e638d49b982fc96       2020-12-12
# 3547100  e4753f517397dec57e638d49b982fc96       2020-12-13
# 4272281  e4753f517397dec57e638d49b982fc96       2020-12-14
# 7871674  e4753f517397dec57e638d49b982fc96       2020-12-15
# 2233242  e4753f517397dec57e638d49b982fc96       2020-12-16
# 2553836  e4753f517397dec57e638d49b982fc96       2020-12-17
# 7506045  e4753f517397dec57e638d49b982fc96       2020-12-18
# 2433799  e4753f517397dec57e638d49b982fc96       2020-12-19
# 1030191  e4753f517397dec57e638d49b982fc96       2020-12-20
# 5807660  e4753f517397dec57e638d49b982fc96       2020-12-21
# 3467214  e4753f517397dec57e638d49b982fc96       2020-12-22
# 7508518  e4753f517397dec57e638d49b982fc96       2020-12-23
# 2336435  e4753f517397dec57e638d49b982fc96       2020-12-24
# 1095414  e4753f517397dec57e638d49b982fc96       2020-12-25
# 408816   e4753f517397dec57e638d49b982fc96       2020-12-26
# 1472755  e4753f517397dec57e638d49b982fc96       2020-12-27
# 694118   e4753f517397dec57e638d49b982fc96       2020-12-28
# 7905351  e4753f517397dec57e638d49b982fc96       2020-12-29
# 7055318  e4753f517397dec57e638d49b982fc96       2020-12-30
# 2433607  e4753f517397dec57e638d49b982fc96       2020-12-31
# 4389365  e4753f517397dec57e638d49b982fc96       2021-01-01
# 3834016  e4753f517397dec57e638d49b982fc96       2021-01-02
# 1471015  e4753f517397dec57e638d49b982fc96       2021-01-03
# 406951   e4753f517397dec57e638d49b982fc96       2021-01-04
# 1154619  e4753f517397dec57e638d49b982fc96       2021-01-05
# 5571430  e4753f517397dec57e638d49b982fc96       2021-01-06
# 6198711  e4753f517397dec57e638d49b982fc96       2021-01-07
# 5571395  e4753f517397dec57e638d49b982fc96       2021-01-08
# 7886827  e4753f517397dec57e638d49b982fc96       2021-01-09
# 2369589  e4753f517397dec57e638d49b982fc96       2021-01-10
# 183161   e4753f517397dec57e638d49b982fc96       2021-01-11
# 1699718  e4753f517397dec57e638d49b982fc96       2021-01-12
# 1816843  e4753f517397dec57e638d49b982fc96       2021-01-13
# 599949   e4753f517397dec57e638d49b982fc96       2021-01-14
# 7738644  e4753f517397dec57e638d49b982fc96       2021-01-15
# 4582719  e4753f517397dec57e638d49b982fc96       2021-01-16
# 6966425  e4753f517397dec57e638d49b982fc96       2021-01-17
# 5033140  e4753f517397dec57e638d49b982fc96       2021-01-18
# 2008097  e4753f517397dec57e638d49b982fc96       2021-01-19
# 2557957  e4753f517397dec57e638d49b982fc96       2021-01-20
# 408710   e4753f517397dec57e638d49b982fc96       2021-01-21
# 7904064  e4753f517397dec57e638d49b982fc96       2021-01-22
# 5587232  e4753f517397dec57e638d49b982fc96       2021-01-23
# 283510   e4753f517397dec57e638d49b982fc96       2021-01-24
# 1019809  e4753f517397dec57e638d49b982fc96       2021-01-25
# 7055326  e4753f517397dec57e638d49b982fc96       2021-01-26
# 1427595  e4753f517397dec57e638d49b982fc96       2021-01-27
# 4272476  e4753f517397dec57e638d49b982fc96       2021-01-28
# 5322817  e4753f517397dec57e638d49b982fc96       2021-01-29
# 3246323  e4753f517397dec57e638d49b982fc96       2021-01-30
# 4278425  e4753f517397dec57e638d49b982fc96       2021-01-31
# 1704454  e4753f517397dec57e638d49b982fc96       2021-02-01
# 7865269  e4753f517397dec57e638d49b982fc96       2021-02-02
# 7740577  e4753f517397dec57e638d49b982fc96       2021-02-03
# 3751653  e4753f517397dec57e638d49b982fc96       2021-02-04
# 1019668  e4753f517397dec57e638d49b982fc96       2021-02-05
# 4899672  e4753f517397dec57e638d49b982fc96       2021-02-06
# 582805   e4753f517397dec57e638d49b982fc96       2021-02-07
# 3835983  e4753f517397dec57e638d49b982fc96       2021-02-08
# 1299632  e4753f517397dec57e638d49b982fc96       2021-02-09
# 106866   e4753f517397dec57e638d49b982fc96       2021-02-10
# 280345   e4753f517397dec57e638d49b982fc96       2021-02-11
# 584437   e4753f517397dec57e638d49b982fc96       2021-02-12
# 4195200  e4753f517397dec57e638d49b982fc96       2021-02-13
# 5923246  e4753f517397dec57e638d49b982fc96       2021-02-14
# 3723999  e4753f517397dec57e638d49b982fc96       2021-02-15
# 1817271  e4753f517397dec57e638d49b982fc96       2021-02-16
# 2366502  e4753f517397dec57e638d49b982fc96       2021-02-17
# 3764702  e4753f517397dec57e638d49b982fc96       2021-02-18
# 699762   e4753f517397dec57e638d49b982fc96       2021-02-19
# 7891314  e4753f517397dec57e638d49b982fc96       2021-02-20
# 2223695  e4753f517397dec57e638d49b982fc96       2021-02-21
# 2217246  e4753f517397dec57e638d49b982fc96       2021-02-22
# 7617364  e4753f517397dec57e638d49b982fc96       2021-02-23
# 5807500  e4753f517397dec57e638d49b982fc96       2021-02-24
# 2230146  e4753f517397dec57e638d49b982fc96       2021-02-25
# 529321   e4753f517397dec57e638d49b982fc96       2021-02-26
# 3863506  e4753f517397dec57e638d49b982fc96       2021-02-27
# 3760562  e4753f517397dec57e638d49b982fc96       2021-02-28
# 1913564  e4753f517397dec57e638d49b982fc96       2021-03-01
# 4278869  e4753f517397dec57e638d49b982fc96       2021-03-02
# 4934559  e4753f517397dec57e638d49b982fc96       2021-03-03
# 5033235  e4753f517397dec57e638d49b982fc96       2021-03-04
# 3828914  e4753f517397dec57e638d49b982fc96       2021-03-05
# 1095078  e4753f517397dec57e638d49b982fc96       2021-03-06
# 699660   e4753f517397dec57e638d49b982fc96       2021-03-07
# 5906365  e4753f517397dec57e638d49b982fc96       2021-03-08
# 587679   e4753f517397dec57e638d49b982fc96       2021-03-09
# 2814789  e4753f517397dec57e638d49b982fc96       2021-03-10
# 5903158  e4753f517397dec57e638d49b982fc96       2021-03-11
# 1911362  e4753f517397dec57e638d49b982fc96       2021-03-12
# 3771005  e4753f517397dec57e638d49b982fc96       2021-03-13
# 6701131  e4753f517397dec57e638d49b982fc96       2021-03-14
# 2317759  e4753f517397dec57e638d49b982fc96       2021-03-15
# 3827372  e4753f517397dec57e638d49b982fc96       2021-03-16
# 4600551  e4753f517397dec57e638d49b982fc96       2021-03-17
# 1725278  e4753f517397dec57e638d49b982fc96       2021-03-18
# 6453235  e4753f517397dec57e638d49b982fc96       2021-03-19
# 4848494  e4753f517397dec57e638d49b982fc96       2021-03-20
# 7889861  e4753f517397dec57e638d49b982fc96       2021-03-21
# 7046985  e4753f517397dec57e638d49b982fc96       2021-03-22
# 6923984  e4753f517397dec57e638d49b982fc96       2021-03-23
# 3506897  e4753f517397dec57e638d49b982fc96       2021-03-24
# 7958453  e4753f517397dec57e638d49b982fc96       2021-03-25
# 7873610  e4753f517397dec57e638d49b982fc96       2021-03-26
# 7889962  e4753f517397dec57e638d49b982fc96       2021-03-27
# 3566375  e4753f517397dec57e638d49b982fc96       2021-03-28
# 3471251  e4753f517397dec57e638d49b982fc96       2021-03-29
# 807852   e4753f517397dec57e638d49b982fc96       2021-03-30
# 4603706  e4753f517397dec57e638d49b982fc96       2021-03-31
# 7905231  e4753f517397dec57e638d49b982fc96       2021-04-01
# 2336334  e4753f517397dec57e638d49b982fc96       2021-04-02
# 6198693  e4753f517397dec57e638d49b982fc96       2021-04-03
# 1254923  e4753f517397dec57e638d49b982fc96       2021-04-04
# 2823410  e4753f517397dec57e638d49b982fc96       2021-04-05
# 6966534  e4753f517397dec57e638d49b982fc96       2021-04-06
# 5586927  e4753f517397dec57e638d49b982fc96       2021-04-07
# 7126439  e4753f517397dec57e638d49b982fc96       2021-04-08
# 7051844  e4753f517397dec57e638d49b982fc96       2021-04-09
# 5903854  e4753f517397dec57e638d49b982fc96       2021-04-10
# 6838654  e4753f517397dec57e638d49b982fc96       2021-04-11
# 7070953  e4753f517397dec57e638d49b982fc96       2021-04-12
# 7740361  e4753f517397dec57e638d49b982fc96       2021-04-13
# 1154988  e4753f517397dec57e638d49b982fc96       2021-04-14
# 408930   e4753f517397dec57e638d49b982fc96       2021-04-15
# 1423671  e4753f517397dec57e638d49b982fc96       2021-04-16
# 7748243  e4753f517397dec57e638d49b982fc96       2021-04-17
# 7581655  e4753f517397dec57e638d49b982fc96       2021-04-18
# 3565580  e4753f517397dec57e638d49b982fc96       2021-04-19
# 3863439  e4753f517397dec57e638d49b982fc96       2021-04-20
# 1715761  e4753f517397dec57e638d49b982fc96       2021-04-21
# 884584   e4753f517397dec57e638d49b982fc96       2021-04-22
# 599808   e4753f517397dec57e638d49b982fc96       2021-04-23
# 700071   e4753f517397dec57e638d49b982fc96       2021-04-24
# 201098   e4753f517397dec57e638d49b982fc96       2021-04-25
# 5531189  e4753f517397dec57e638d49b982fc96       2021-04-26
# 594871   e4753f517397dec57e638d49b982fc96       2021-04-27
# 2814948  e4753f517397dec57e638d49b982fc96       2021-04-28
# 530898   e4753f517397dec57e638d49b982fc96       2021-04-29
# 2319719  e4753f517397dec57e638d49b982fc96       2021-04-30
# 2335871  e4753f517397dec57e638d49b982fc96       2021-05-01
# 8059144  e4753f517397dec57e638d49b982fc96       2021-05-02
# 526052   e4753f517397dec57e638d49b982fc96       2021-05-03
# 7051577  e4753f517397dec57e638d49b982fc96       2021-05-04
# 7051827  e4753f517397dec57e638d49b982fc96       2021-05-05
# 1928224  e4753f517397dec57e638d49b982fc96       2021-05-06
# 5029614  e4753f517397dec57e638d49b982fc96       2021-05-07
# 3333776  e4753f517397dec57e638d49b982fc96       2021-05-08
# 1642588  e4753f517397dec57e638d49b982fc96       2021-05-09
# 2001732  e4753f517397dec57e638d49b982fc96       2021-05-10
# 5082363  e4753f517397dec57e638d49b982fc96       2021-05-11
# 2334421  e4753f517397dec57e638d49b982fc96       2021-05-12
# 107513   e4753f517397dec57e638d49b982fc96       2021-05-13
# 1254618  e4753f517397dec57e638d49b982fc96       2021-05-14
# 1257966  e4753f517397dec57e638d49b982fc96       2021-05-15
# 3546378  e4753f517397dec57e638d49b982fc96       2021-05-16
# 7867746  e4753f517397dec57e638d49b982fc96       2021-05-17
# 2004730  e4753f517397dec57e638d49b982fc96       2021-05-18
# 5587470  e4753f517397dec57e638d49b982fc96       2021-05-19
# 2820999  e4753f517397dec57e638d49b982fc96       2021-05-20
# 7873822  e4753f517397dec57e638d49b982fc96       2021-05-21
# 7902306  e4753f517397dec57e638d49b982fc96       2021-05-22
# 5301265  e4753f517397dec57e638d49b982fc96       2021-05-23
# 2372106  e4753f517397dec57e638d49b982fc96       2021-05-24
# 5022663  e4753f517397dec57e638d49b982fc96       2021-05-25
# 5904164  e4753f517397dec57e638d49b982fc96       2021-05-26
# 582901   e4753f517397dec57e638d49b982fc96       2021-05-27
# 2334028  e4753f517397dec57e638d49b982fc96       2021-05-28
# 586813   e4753f517397dec57e638d49b982fc96       2021-05-29
# 6839219  e4753f517397dec57e638d49b982fc96       2021-05-30
# 2558192  e4753f517397dec57e638d49b982fc96       2021-05-31
# 3869685  e4753f517397dec57e638d49b982fc96       2021-06-01
# 1423889  e4753f517397dec57e638d49b982fc96       2021-06-02
# 6415212  e4753f517397dec57e638d49b982fc96       2021-06-03
# 2437546  e4753f517397dec57e638d49b982fc96       2021-06-04
# 1659376  e4753f517397dec57e638d49b982fc96       2021-06-05
# 3246163  e4753f517397dec57e638d49b982fc96       2021-06-06
# 693480   e4753f517397dec57e638d49b982fc96       2021-06-07
# 5082324  e4753f517397dec57e638d49b982fc96       2021-06-08
# 5023517  e4753f517397dec57e638d49b982fc96       2021-06-09
# 3717957  e4753f517397dec57e638d49b982fc96       2021-06-10
# 1819847  e4753f517397dec57e638d49b982fc96       2021-06-11
# 2993565  e4753f517397dec57e638d49b982fc96       2021-06-12
# 5591714  e4753f517397dec57e638d49b982fc96       2021-06-13
# 5904407  e4753f517397dec57e638d49b982fc96       2021-06-14
# 2408174  e4753f517397dec57e638d49b982fc96       2021-06-15
# 3771308  e4753f517397dec57e638d49b982fc96       2021-06-16
# 5577360  e4753f517397dec57e638d49b982fc96       2021-06-17
# 7886568  e4753f517397dec57e638d49b982fc96       2021-06-18
# 5571967  e4753f517397dec57e638d49b982fc96       2021-06-19
# 201427   e4753f517397dec57e638d49b982fc96       2021-06-20
# 3038807  e4753f517397dec57e638d49b982fc96       2021-06-21
# 7058423  e4753f517397dec57e638d49b982fc96       2021-06-22
# 7748768  e4753f517397dec57e638d49b982fc96       2021-06-23
# 6453736  e4753f517397dec57e638d49b982fc96       2021-06-24
# 173496   e4753f517397dec57e638d49b982fc96       2021-06-25
# 7058535  e4753f517397dec57e638d49b982fc96       2021-06-26
# 122485   e4753f517397dec57e638d49b982fc96       2021-06-27
# 2233284  e4753f517397dec57e638d49b982fc96       2021-06-28
# 5031617  e4753f517397dec57e638d49b982fc96       2021-06-29
# 4431315  e4753f517397dec57e638d49b982fc96       2021-06-30
# 5026758  e4753f517397dec57e638d49b982fc96       2021-07-01
# 4940324  e4753f517397dec57e638d49b982fc96       2021-07-02
# 3040335  e4753f517397dec57e638d49b982fc96       2021-07-03
# 2432902  e4753f517397dec57e638d49b982fc96       2021-07-04
# 5903640  e4753f517397dec57e638d49b982fc96       2021-07-05
# 3331005  e4753f517397dec57e638d49b982fc96       2021-07-06
# 3570482  e4753f517397dec57e638d49b982fc96       2021-07-07
# 2979413  e4753f517397dec57e638d49b982fc96       2021-07-08
# 1427575  e4753f517397dec57e638d49b982fc96       2021-07-09
# 803811   e4753f517397dec57e638d49b982fc96       2021-07-10
# 2334212  e4753f517397dec57e638d49b982fc96       2021-07-11
# 5535598  e4753f517397dec57e638d49b982fc96       2021-07-12
# 590046   e4753f517397dec57e638d49b982fc96       2021-07-13
# 5009896  e4753f517397dec57e638d49b982fc96       2021-07-14
# 4732214  e4753f517397dec57e638d49b982fc96       2021-07-15
# 7085024  e4753f517397dec57e638d49b982fc96       2021-07-16
# 2435950  e4753f517397dec57e638d49b982fc96       2021-07-17
# 2979325  e4753f517397dec57e638d49b982fc96       2021-07-18
# 590166   e4753f517397dec57e638d49b982fc96       2021-07-19
# 1518065  e4753f517397dec57e638d49b982fc96       2021-07-20
# 2004059  e4753f517397dec57e638d49b982fc96       2021-07-21
# 6369588  e4753f517397dec57e638d49b982fc96       2021-07-22
# 6357751  e4753f517397dec57e638d49b982fc96       2021-07-23
# 3246284  e4753f517397dec57e638d49b982fc96       2021-07-24
# 6707369  e4753f517397dec57e638d49b982fc96       2021-07-25
# 2366567  e4753f517397dec57e638d49b982fc96       2021-07-26
# 5570146  e4753f517397dec57e638d49b982fc96       2021-07-27
# 3243865  e4753f517397dec57e638d49b982fc96       2021-07-28
# 283432   e4753f517397dec57e638d49b982fc96       2021-07-29
# 5531168  e4753f517397dec57e638d49b982fc96       2021-07-30
# 6709266  e4753f517397dec57e638d49b982fc96       2021-07-31
# 6157932  e4753f517397dec57e638d49b982fc96       2021-08-01
# 887034   e4753f517397dec57e638d49b982fc96       2021-08-02
# 4268146  e4753f517397dec57e638d49b982fc96       2021-08-03
# 1095191  e4753f517397dec57e638d49b982fc96       2021-08-04
# 2776638  e4753f517397dec57e638d49b982fc96       2021-08-05
# 4934040  e4753f517397dec57e638d49b982fc96       2021-08-06
# 4890626  e4753f517397dec57e638d49b982fc96       2021-08-07
# 3246527  e4753f517397dec57e638d49b982fc96       2021-08-08
# 4575528  e4753f517397dec57e638d49b982fc96       2021-08-09
# 4582377  e4753f517397dec57e638d49b982fc96       2021-08-10
# 6967010  e4753f517397dec57e638d49b982fc96       2021-08-11
# 6011229  e4753f517397dec57e638d49b982fc96       2021-08-12
# 4651550  e4753f517397dec57e638d49b982fc96       2021-08-13
# 2814419  e4753f517397dec57e638d49b982fc96       2021-08-14
# 1517803  e4753f517397dec57e638d49b982fc96       2021-08-15
# 4848408  e4753f517397dec57e638d49b982fc96       2021-08-16
# 6700614  e4753f517397dec57e638d49b982fc96       2021-08-17
# 883911   e4753f517397dec57e638d49b982fc96       2021-08-18
# 2367040  e4753f517397dec57e638d49b982fc96       2021-08-19
# 582850   e4753f517397dec57e638d49b982fc96       2021-08-20
# 2225777  e4753f517397dec57e638d49b982fc96       2021-08-21
# 3510514  e4753f517397dec57e638d49b982fc96       2021-08-22
# 4733789  e4753f517397dec57e638d49b982fc96       2021-08-23
# 7052112  e4753f517397dec57e638d49b982fc96       2021-08-24
# 3869521  e4753f517397dec57e638d49b982fc96       2021-08-25
# 7873543  e4753f517397dec57e638d49b982fc96       2021-08-26
# 2334587  e4753f517397dec57e638d49b982fc96       2021-08-27
# 2316604  e4753f517397dec57e638d49b982fc96       2021-08-28
# 1814427  e4753f517397dec57e638d49b982fc96       2021-08-29
# 6969242  e4753f517397dec57e638d49b982fc96       2021-08-30
# 107264   e4753f517397dec57e638d49b982fc96       2021-08-31
# 153120   e4753f517397dec57e638d49b982fc96       2021-09-01
# 590354   e4753f517397dec57e638d49b982fc96       2021-09-02
# 7385560  e4753f517397dec57e638d49b982fc96       2021-09-03
# 2433659  e4753f517397dec57e638d49b982fc96       2021-09-04
# 755586   e4753f517397dec57e638d49b982fc96       2021-09-05
# 5570117  e4753f517397dec57e638d49b982fc96       2021-09-06
# 7887006  e4753f517397dec57e638d49b982fc96       2021-09-07
# 599621   e4753f517397dec57e638d49b982fc96       2021-09-08
# 6967030  e4753f517397dec57e638d49b982fc96       2021-09-09
# 173801   e4753f517397dec57e638d49b982fc96       2021-09-10
# 6706901  e4753f517397dec57e638d49b982fc96       2021-09-11
# 1154902  e4753f517397dec57e638d49b982fc96       2021-09-12
# 1470703  e4753f517397dec57e638d49b982fc96       2021-09-13
# 2435777  e4753f517397dec57e638d49b982fc96       2021-09-14
# 2320002  e4753f517397dec57e638d49b982fc96       2021-09-15
# 6925455  e4753f517397dec57e638d49b982fc96       2021-09-16
# 6935721  e4753f517397dec57e638d49b982fc96       2021-09-17
# 1925301  e4753f517397dec57e638d49b982fc96       2021-09-18
# 407297   e4753f517397dec57e638d49b982fc96       2021-09-19
# 7582081  e4753f517397dec57e638d49b982fc96       2021-09-20
# 7873082  e4753f517397dec57e638d49b982fc96       2021-09-21
# 7758838  e4753f517397dec57e638d49b982fc96       2021-09-22
# 7060924  e4753f517397dec57e638d49b982fc96       2021-09-23
# 2374738  e4753f517397dec57e638d49b982fc96       2021-09-24
# 886825   e4753f517397dec57e638d49b982fc96       2021-09-25
# 7129964  e4753f517397dec57e638d49b982fc96       2021-09-26
# 2370268  e4753f517397dec57e638d49b982fc96       2021-09-27
# 1299575  e4753f517397dec57e638d49b982fc96       2021-09-28
# 1925792  e4753f517397dec57e638d49b982fc96       2021-09-29
# 2004661  e4753f517397dec57e638d49b982fc96       2021-09-30
# 3546745  e4753f517397dec57e638d49b982fc96       2021-10-01
# 1715906  e4753f517397dec57e638d49b982fc96       2021-10-02
# 7953879  e4753f517397dec57e638d49b982fc96       2021-10-03
# 2317524  e4753f517397dec57e638d49b982fc96       2021-10-04
# 121947   e4753f517397dec57e638d49b982fc96       2021-10-05
# 2432658  e4753f517397dec57e638d49b982fc96       2021-10-06
# 6923761  e4753f517397dec57e638d49b982fc96       2021-10-07
# 5920738  e4753f517397dec57e638d49b982fc96       2021-10-08
# 7175884  e4753f517397dec57e638d49b982fc96       2021-10-09
# 2223802  e4753f517397dec57e638d49b982fc96       2021-10-10
# 3038763  e4753f517397dec57e638d49b982fc96       2021-10-11
# 3040814  e4753f517397dec57e638d49b982fc96       2021-10-12
# 1623997  e4753f517397dec57e638d49b982fc96       2021-10-13
# 7958656  e4753f517397dec57e638d49b982fc96       2021-10-14
# 1299587  e4753f517397dec57e638d49b982fc96       2021-10-15
# 4939963  e4753f517397dec57e638d49b982fc96       2021-10-16
# 5923074  e4753f517397dec57e638d49b982fc96       2021-10-17
# 5033607  e4753f517397dec57e638d49b982fc96       2021-10-18
# 8060892  e4753f517397dec57e638d49b982fc96       2021-10-19
# 3038570  e4753f517397dec57e638d49b982fc96       2021-10-20
# 7616634  e4753f517397dec57e638d49b982fc96       2021-10-21
# 6710711  e4753f517397dec57e638d49b982fc96       2021-10-22
# 162024   e4753f517397dec57e638d49b982fc96       2021-10-23
# 2004315  e4753f517397dec57e638d49b982fc96       2021-10-24
# 1095205  e4753f517397dec57e638d49b982fc96       2021-10-25
# 3829136  e4753f517397dec57e638d49b982fc96       2021-10-26
# 3040343  e4753f517397dec57e638d49b982fc96       2021-10-27
# 7615290  e4753f517397dec57e638d49b982fc96       2021-10-28
# 2364130  e4753f517397dec57e638d49b982fc96       2021-10-29
# 1155052  e4753f517397dec57e638d49b982fc96       2021-10-30
# 881596   e4753f517397dec57e638d49b982fc96       2021-10-31
# 3760894  e4753f517397dec57e638d49b982fc96       2021-11-01
# 2363972  e4753f517397dec57e638d49b982fc96       2021-11-02
# 6700528  e4753f517397dec57e638d49b982fc96       2021-11-03
# 535110   e4753f517397dec57e638d49b982fc96       2021-11-04
# 3829190  e4753f517397dec57e638d49b982fc96       2021-11-05
# 3860447  e4753f517397dec57e638d49b982fc96       2021-11-06
# 7386091  e4753f517397dec57e638d49b982fc96       2021-11-07
# 1299927  e4753f517397dec57e638d49b982fc96       2021-11-08
# 1176481  e4753f517397dec57e638d49b982fc96       2021-11-09
# 6266467  e4753f517397dec57e638d49b982fc96       2021-11-10
# 152935   e4753f517397dec57e638d49b982fc96       2021-11-11
# 6701215  e4753f517397dec57e638d49b982fc96       2021-11-12
# 5033518  e4753f517397dec57e638d49b982fc96       2021-11-13
# 8060808  e4753f517397dec57e638d49b982fc96       2021-11-14
# 3828832  e4753f517397dec57e638d49b982fc96       2021-11-15
# 7068705  e4753f517397dec57e638d49b982fc96       2021-11-16
# 2001897  e4753f517397dec57e638d49b982fc96       2021-11-17
# 2820302  e4753f517397dec57e638d49b982fc96       2021-11-18
# 2820975  e4753f517397dec57e638d49b982fc96       2021-11-19
# 1296666  e4753f517397dec57e638d49b982fc96       2021-11-20
# 2230132  e4753f517397dec57e638d49b982fc96       2021-11-21
# 7616594  e4753f517397dec57e638d49b982fc96       2021-11-22
# 6157837  e4753f517397dec57e638d49b982fc96       2021-11-23
# 2435687  e4753f517397dec57e638d49b982fc96       2021-11-24
# 1704633  e4753f517397dec57e638d49b982fc96       2021-11-25
# 1699245  e4753f517397dec57e638d49b982fc96       2021-11-26
# 3040940  e4753f517397dec57e638d49b982fc96       2021-11-27
# 3561452  e4753f517397dec57e638d49b982fc96       2021-11-28
# 694003   e4753f517397dec57e638d49b982fc96       2021-11-29
# 6168161  e4753f517397dec57e638d49b982fc96       2021-11-30
# 7581946  e4753f517397dec57e638d49b982fc96       2021-12-01
# 531143   e4753f517397dec57e638d49b982fc96       2021-12-02
# 5904797  e4753f517397dec57e638d49b982fc96       2021-12-03
# 5903443  e4753f517397dec57e638d49b982fc96       2021-12-04
# 2316607  e4753f517397dec57e638d49b982fc96       2021-12-05
# 5323337  e4753f517397dec57e638d49b982fc96       2021-12-06
# 1257550  e4753f517397dec57e638d49b982fc96       2021-12-07
# 7865802  e4753f517397dec57e638d49b982fc96       2021-12-08
# 4195177  e4753f517397dec57e638d49b982fc96       2021-12-09
# 5577380  e4753f517397dec57e638d49b982fc96       2021-12-10
# 1912864  e4753f517397dec57e638d49b982fc96       2021-12-11
# 591812   e4753f517397dec57e638d49b982fc96       2021-12-12
# 5080252  e4753f517397dec57e638d49b982fc96       2021-12-13
# 613498   e4753f517397dec57e638d49b982fc96       2021-12-14
# 7617401  e4753f517397dec57e638d49b982fc96       2021-12-15
# 2562708  e4753f517397dec57e638d49b982fc96       2021-12-16
# 7912768  e4753f517397dec57e638d49b982fc96       2021-12-17
# 7694864  e4753f517397dec57e638d49b982fc96       2021-12-18
# 590450   e4753f517397dec57e638d49b982fc96       2021-12-19
# 7886599  e4753f517397dec57e638d49b982fc96       2021-12-20
# 2008529  e4753f517397dec57e638d49b982fc96       2021-12-21
# 2437025  e4753f517397dec57e638d49b982fc96       2021-12-22
# 580265   e4753f517397dec57e638d49b982fc96       2021-12-23
# 7756201  e4753f517397dec57e638d49b982fc96       2021-12-24
# 6976043  e4753f517397dec57e638d49b982fc96       2021-12-25
# 1470975  e4753f517397dec57e638d49b982fc96       2021-12-26
# 1019259  e4753f517397dec57e638d49b982fc96       2021-12-27
# 2433815  e4753f517397dec57e638d49b982fc96       2021-12-28
# 6714377  e4753f517397dec57e638d49b982fc96       2021-12-29
# 593040   e4753f517397dec57e638d49b982fc96       2021-12-30
# 2553416  e4753f517397dec57e638d49b982fc96       2021-12-31
# 621724   e4753f517397dec57e638d49b982fc96       2022-01-01
# 1151095  e4753f517397dec57e638d49b982fc96       2022-01-02
# 6924394  e4753f517397dec57e638d49b982fc96       2022-01-03
# 2014163  e4753f517397dec57e638d49b982fc96       2022-01-04
# 2976313  e4753f517397dec57e638d49b982fc96       2022-01-05
# 2823712  e4753f517397dec57e638d49b982fc96       2022-01-06
# 6033566  e4753f517397dec57e638d49b982fc96       2022-01-07
# 2820630  e4753f517397dec57e638d49b982fc96       2022-01-08
# 7912705  e4753f517397dec57e638d49b982fc96       2022-01-09
# 7582091  e4753f517397dec57e638d49b982fc96       2022-01-10
# 5923957  e4753f517397dec57e638d49b982fc96       2022-01-11
# 7910741  e4753f517397dec57e638d49b982fc96       2022-01-12
# 6838998  e4753f517397dec57e638d49b982fc96       2022-01-13
# 4804436  e4753f517397dec57e638d49b982fc96       2022-01-14
# 2375083  e4753f517397dec57e638d49b982fc96       2022-01-15
# 5788493  e4753f517397dec57e638d49b982fc96       2022-01-16
# 4852047  e4753f517397dec57e638d49b982fc96       2022-01-17
# 4845355  e4753f517397dec57e638d49b982fc96       2022-01-18
# 2998271  e4753f517397dec57e638d49b982fc96       2022-01-19
# 6197582  e4753f517397dec57e638d49b982fc96       2022-01-20
# 4738105  e4753f517397dec57e638d49b982fc96       2022-01-21
# 1297340  e4753f517397dec57e638d49b982fc96       2022-01-22
# 1151859  e4753f517397dec57e638d49b982fc96       2022-01-23
# 6708937  e4753f517397dec57e638d49b982fc96       2022-01-24
# 1725374  e4753f517397dec57e638d49b982fc96       2022-01-25
# 4268355  e4753f517397dec57e638d49b982fc96       2022-01-26
# 1151392  e4753f517397dec57e638d49b982fc96       2022-01-27
# 1094912  e4753f517397dec57e638d49b982fc96       2022-01-28
# 6924780  e4753f517397dec57e638d49b982fc96       2022-01-29
# 2558407  e4753f517397dec57e638d49b982fc96       2022-01-30
# 1598666  e4753f517397dec57e638d49b982fc96       2022-01-31
# 7058787  e4753f517397dec57e638d49b982fc96       2022-02-01
# 2131462  e4753f517397dec57e638d49b982fc96       2022-02-02
# 2976085  e4753f517397dec57e638d49b982fc96       2022-02-03
# 7177245  e4753f517397dec57e638d49b982fc96       2022-02-04
# 6162994  e4753f517397dec57e638d49b982fc96       2022-02-05
# 6611725  e4753f517397dec57e638d49b982fc96       2022-02-06
# 7870931  e4753f517397dec57e638d49b982fc96       2022-02-07
# 283024   e4753f517397dec57e638d49b982fc96       2022-02-08
# 2375443  e4753f517397dec57e638d49b982fc96       2022-02-09
# 2372341  e4753f517397dec57e638d49b982fc96       2022-02-10
# 7904812  e4753f517397dec57e638d49b982fc96       2022-02-11
# 6450435  e4753f517397dec57e638d49b982fc96       2022-02-12
# 609447   e4753f517397dec57e638d49b982fc96       2022-02-13
# 755520   e4753f517397dec57e638d49b982fc96       2022-02-14
# 7763211  e4753f517397dec57e638d49b982fc96       2022-02-15
# 4220024  e4753f517397dec57e638d49b982fc96       2022-02-16
# 2001092  e4753f517397dec57e638d49b982fc96       2022-02-17
# 2371938  e4753f517397dec57e638d49b982fc96       2022-02-18
# 1847414  e4753f517397dec57e638d49b982fc96       2022-02-19
# 5301301  e4753f517397dec57e638d49b982fc96       2022-02-20
# 6711416  e4753f517397dec57e638d49b982fc96       2022-02-21
# 2436252  e4753f517397dec57e638d49b982fc96       2022-02-22
# 594020   e4753f517397dec57e638d49b982fc96       2022-02-23
# 1910973  e4753f517397dec57e638d49b982fc96       2022-02-24
# 1258448  e4753f517397dec57e638d49b982fc96       2022-02-25
# 6925910  e4753f517397dec57e638d49b982fc96       2022-02-26
# 7958333  e4753f517397dec57e638d49b982fc96       2022-02-27
# 8059283  e4753f517397dec57e638d49b982fc96       2022-02-28
# 7615520  e4753f517397dec57e638d49b982fc96       2022-03-01
# 7913239  e4753f517397dec57e638d49b982fc96       2022-03-02
# 7886546  e4753f517397dec57e638d49b982fc96       2022-03-03
# 6966756  e4753f517397dec57e638d49b982fc96       2022-03-04
# 2435599  e4753f517397dec57e638d49b982fc96       2022-03-05
# 5080449  e4753f517397dec57e638d49b982fc96       2022-03-06
# 1471177  e4753f517397dec57e638d49b982fc96       2022-03-07
# 4278897  e4753f517397dec57e638d49b982fc96       2022-03-08
# 2433795  e4753f517397dec57e638d49b982fc96       2022-03-09
# 3757158  e4753f517397dec57e638d49b982fc96       2022-03-10
# 5322710  e4753f517397dec57e638d49b982fc96       2022-03-11
# 622078   e4753f517397dec57e638d49b982fc96       2022-03-12
# 5531786  e4753f517397dec57e638d49b982fc96       2022-03-13
# 7958368  e4753f517397dec57e638d49b982fc96       2022-03-14
# 201913   e4753f517397dec57e638d49b982fc96       2022-03-15
# 2435283  e4753f517397dec57e638d49b982fc96       2022-03-16
# 6709635  e4753f517397dec57e638d49b982fc96       2022-03-17
# 4198457  e4753f517397dec57e638d49b982fc96       2022-03-18
# 3761036  e4753f517397dec57e638d49b982fc96       2022-03-19
# 5576710  e4753f517397dec57e638d49b982fc96       2022-03-20
# 2433694  e4753f517397dec57e638d49b982fc96       2022-03-21
# 1623970  e4753f517397dec57e638d49b982fc96       2022-03-22
# 3869475  e4753f517397dec57e638d49b982fc96       2022-03-23
# 1643037  e4753f517397dec57e638d49b982fc96       2022-03-24
# 5082469  e4753f517397dec57e638d49b982fc96       2022-03-25
# 619292   e4753f517397dec57e638d49b982fc96       2022-03-26
# 4278474  e4753f517397dec57e638d49b982fc96       2022-03-27
# 1909703  e4753f517397dec57e638d49b982fc96       2022-03-28
# 6036926  e4753f517397dec57e638d49b982fc96       2022-03-29
# 2004453  e4753f517397dec57e638d49b982fc96       2022-03-30
# 4647366  e4753f517397dec57e638d49b982fc96       2022-03-31
# 2437430  e4753f517397dec57e638d49b982fc96       2022-04-01
# 526042   e4753f517397dec57e638d49b982fc96       2022-04-02
# 3723347  e4753f517397dec57e638d49b982fc96       2022-04-03
# 4575555  e4753f517397dec57e638d49b982fc96       2022-04-04
# 4788112  e4753f517397dec57e638d49b982fc96       2022-04-05
# 7130051  e4753f517397dec57e638d49b982fc96       2022-04-06
# 2435248  e4753f517397dec57e638d49b982fc96       2022-04-07
# 5033594  e4753f517397dec57e638d49b982fc96       2022-04-08
# 280033   e4753f517397dec57e638d49b982fc96       2022-04-09
# 1704551  e4753f517397dec57e638d49b982fc96       2022-04-10
# 3561253  e4753f517397dec57e638d49b982fc96       2022-04-11
# 6269975  e4753f517397dec57e638d49b982fc96       2022-04-12
# 4198543  e4753f517397dec57e638d49b982fc96       2022-04-13
# 5009885  e4753f517397dec57e638d49b982fc96       2022-04-14
# 3572981  e4753f517397dec57e638d49b982fc96       2022-04-15
# ...
# 1925680                   NaN
# 6045181                   NaN
# 6838364                   NaN
# 3546418                   NaN
# 1471218                   NaN
# 7952590                   NaN
# 7175886                   NaN
# 7508254                   NaN
# 3547100                   NaN
# 4272281                   NaN
# 7871674                   NaN
# 2233242                   NaN
# 2553836                   NaN
# 7506045                   NaN
# 2433799                   NaN
# 1030191                   NaN
# 5807660                   NaN
# 3467214                   NaN
# 7508518                   NaN
# 2336435                   NaN
# 1095414                   NaN
# 408816                    NaN
# 1472755                   NaN
# 694118                    NaN
# 7905351                   NaN
# 7055318                   NaN
# 2433607                   NaN
# 4389365                   NaN
# 3834016                   NaN
# 1471015                   NaN
# 406951                    NaN
# 1154619                   NaN
# 5571430                   NaN
# 6198711                   NaN
# 5571395                   NaN
# 7886827                   NaN
# 2369589                   NaN
# 183161                    NaN
# 1699718                   NaN
# 1816843                   NaN
# 599949                    NaN
# 7738644                   NaN
# 4582719                   NaN
# 6966425                   NaN
# 5033140                   NaN
# 2008097                   NaN
# 2557957                   NaN
# 408710                    NaN
# 7904064                   NaN
# 5587232                   NaN
# 283510                    NaN
# 1019809                   NaN
# 7055326                   NaN
# 1427595                   NaN
# 4272476                   NaN
# 5322817                   NaN
# 3246323                   NaN
# 4278425                   NaN
# 1704454                   NaN
# 7865269                   NaN
# 7740577                   NaN
# 3751653                   NaN
# 1019668                   NaN
# 4899672                   NaN
# 582805                    NaN
# 3835983                   NaN
# 1299632                   NaN
# 106866                    NaN
# 280345                    NaN
# 584437                    NaN
# 4195200                   NaN
# 5923246                   NaN
# 3723999                   NaN
# 1817271                   NaN
# 2366502                   NaN
# 3764702                   NaN
# 699762                    NaN
# 7891314                   NaN
# 2223695                   NaN
# 2217246                   NaN
# 7617364                   NaN
# 5807500                   NaN
# 2230146                   NaN
# 529321                    NaN
# 3863506                   NaN
# 3760562                   NaN
# 1913564                   NaN
# 4278869                   NaN
# 4934559                   NaN
# 5033235                   NaN
# 3828914                   NaN
# 1095078                   NaN
# 699660                    NaN
# 5906365                   NaN
# 587679                    NaN
# 2814789                   NaN
# 5903158                   NaN
# 1911362                   NaN
# 3771005                   NaN
# 6701131                   NaN
# 2317759                   NaN
# 3827372                   NaN
# 4600551                   NaN
# 1725278                   NaN
# 6453235                   NaN
# 4848494                   NaN
# 7889861                   NaN
# 7046985                   NaN
# 6923984                   NaN
# 3506897                   NaN
# 7958453                   NaN
# 7873610                   NaN
# 7889962                   NaN
# 3566375                   NaN
# 3471251                   NaN
# 807852                    NaN
# 4603706                   NaN
# 7905231                   NaN
# 2336334                   NaN
# 6198693                   NaN
# 1254923                   NaN
# 2823410                   NaN
# 6966534                   NaN
# 5586927                   NaN
# 7126439                   NaN
# 7051844                   NaN
# 5903854                   NaN
# 6838654                   NaN
# 7070953                   NaN
# 7740361                   NaN
# 1154988                   NaN
# 408930                    NaN
# 1423671                   NaN
# 7748243                   NaN
# 7581655                   NaN
# 3565580                   NaN
# 3863439                   NaN
# 1715761                   NaN
# 884584                    NaN
# 599808                    NaN
# 700071                    NaN
# 201098                    NaN
# 5531189                   NaN
# 594871                    NaN
# 2814948                   NaN
# 530898                    NaN
# 2319719                   NaN
# 2335871                   NaN
# 8059144                   NaN
# 526052                    NaN
# 7051577                   NaN
# 7051827                   NaN
# 1928224                   NaN
# 5029614                   NaN
# 3333776                   NaN
# 1642588                   NaN
# 2001732                   NaN
# 5082363                   NaN
# 2334421                   NaN
# 107513                    NaN
# 1254618                   NaN
# 1257966                   NaN
# 3546378                   NaN
# 7867746                   NaN
# 2004730                   NaN
# 5587470                   NaN
# 2820999                   NaN
# 7873822                   NaN
# 7902306                   NaN
# 5301265                   NaN
# 2372106                   NaN
# 5022663                   NaN
# 5904164                   NaN
# 582901                    NaN
# 2334028                   NaN
# 586813                    NaN
# 6839219                   NaN
# 2558192                   NaN
# 3869685                   NaN
# 1423889                   NaN
# 6415212                   NaN
# 2437546                   NaN
# 1659376                   NaN
# 3246163                   NaN
# 693480                    NaN
# 5082324                   NaN
# 5023517                   NaN
# 3717957                   NaN
# 1819847                   NaN
# 2993565                   NaN
# 5591714                   NaN
# 5904407                   NaN
# 2408174                   NaN
# 3771308                   NaN
# 5577360                   NaN
# 7886568                   NaN
# 5571967                   NaN
# 201427                    NaN
# 3038807                   NaN
# 7058423                   NaN
# 7748768                   NaN
# 6453736                   NaN
# 173496                    NaN
# 7058535                   NaN
# 122485                    NaN
# 2233284                   NaN
# 5031617                   NaN
# 4431315                   NaN
# 5026758                   NaN
# 4940324                   NaN
# 3040335                   NaN
# 2432902                   NaN
# 5903640                   NaN
# 3331005                   NaN
# 3570482                   NaN
# 2979413                   NaN
# 1427575                   NaN
# 803811                    NaN
# 2334212                   NaN
# 5535598                   NaN
# 590046                    NaN
# 5009896                   NaN
# 4732214                   NaN
# 7085024                   NaN
# 2435950                   NaN
# 2979325                   NaN
# 590166                    NaN
# 1518065                   NaN
# 2004059                   NaN
# 6369588                   NaN
# 6357751                   NaN
# 3246284                   NaN
# 6707369                   NaN
# 2366567                   NaN
# 5570146                   NaN
# 3243865                   NaN
# 283432                    NaN
# 5531168                   NaN
# 6709266                   NaN
# 6157932                   NaN
# 887034                    NaN
# 4268146                   NaN
# 1095191                   NaN
# 2776638                   NaN
# 4934040                   NaN
# 4890626                   NaN
# 3246527                   NaN
# 4575528                   NaN
# 4582377                   NaN
# 6967010                   NaN
# 6011229                   NaN
# 4651550                   NaN
# 2814419                   NaN
# 1517803                   NaN
# 4848408                   NaN
# 6700614                   NaN
# 883911                    NaN
# 2367040                   NaN
# 582850                    NaN
# 2225777                   NaN
# 3510514                   NaN
# 4733789                   NaN
# 7052112                   NaN
# 3869521                   NaN
# 7873543                   NaN
# 2334587                   NaN
# 2316604                   NaN
# 1814427                   NaN
# 6969242                   NaN
# 107264                    NaN
# 153120                    NaN
# 590354                    NaN
# 7385560                   NaN
# 2433659                   NaN
# 755586                    NaN
# 5570117                   NaN
# 7887006                   NaN
# 599621                    NaN
# 6967030                   NaN
# 173801                    NaN
# 6706901                   NaN
# 1154902                   NaN
# 1470703                   NaN
# 2435777                   NaN
# 2320002                   NaN
# 6925455                   NaN
# 6935721                   NaN
# 1925301                   NaN
# 407297                    NaN
# 7582081                   NaN
# 7873082                   NaN
# 7758838                   NaN
# 7060924                   NaN
# 2374738                   NaN
# 886825                    NaN
# 7129964                   NaN
# 2370268                   NaN
# 1299575                   NaN
# 1925792                   NaN
# 2004661                   NaN
# 3546745                   NaN
# 1715906                   NaN
# 7953879                   NaN
# 2317524                   NaN
# 121947                    NaN
# 2432658                   NaN
# 6923761                   NaN
# 5920738                   NaN
# 7175884                   NaN
# 2223802                   NaN
# 3038763                   NaN
# 3040814                   NaN
# 1623997                   NaN
# 7958656                   NaN
# 1299587                   NaN
# 4939963                   NaN
# 5923074                   NaN
# 5033607                   NaN
# 8060892                   NaN
# 3038570                   NaN
# 7616634                   NaN
# 6710711                   NaN
# 162024                    NaN
# 2004315                   NaN
# 1095205                   NaN
# 3829136                   NaN
# 3040343                   NaN
# 7615290                   NaN
# 2364130                   NaN
# 1155052                   NaN
# 881596                    NaN
# 3760894                   NaN
# 2363972                   NaN
# 6700528                   NaN
# 535110                    NaN
# 3829190                   NaN
# 3860447                   NaN
# 7386091                   NaN
# 1299927                   NaN
# 1176481                   NaN
# 6266467                   NaN
# 152935                    NaN
# 6701215                   NaN
# 5033518                   NaN
# 8060808                   NaN
# 3828832                   NaN
# 7068705                   NaN
# 2001897                   NaN
# 2820302                   NaN
# 2820975                   NaN
# 1296666                   NaN
# 2230132                   NaN
# 7616594                   NaN
# 6157837                   NaN
# 2435687                   NaN
# 1704633                   NaN
# 1699245                   NaN
# 3040940                   NaN
# 3561452                   NaN
# 694003                    NaN
# 6168161                   NaN
# 7581946                   NaN
# 531143                    NaN
# 5904797                   NaN
# 5903443                   NaN
# 2316607                   NaN
# 5323337                   NaN
# 1257550                   NaN
# 7865802                   NaN
# 4195177                   NaN
# 5577380                   NaN
# 1912864                   NaN
# 591812                    NaN
# 5080252                   NaN
# 613498                    NaN
# 7617401                   NaN
# 2562708                   NaN
# 7912768                   NaN
# 7694864                   NaN
# 590450                    NaN
# 7886599                   NaN
# 2008529                   NaN
# 2437025                   NaN
# 580265                    NaN
# 7756201                   NaN
# 6976043                   NaN
# 1470975                   NaN
# 1019259                   NaN
# 2433815                   NaN
# 6714377                   NaN
# 593040                    NaN
# 2553416                   NaN
# 621724                    NaN
# 1151095                   NaN
# 6924394                   NaN
# 2014163                   NaN
# 2976313                   NaN
# 2823712                   NaN
# 6033566                   NaN
# 2820630                   NaN
# 7912705                   NaN
# 7582091                   NaN
# 5923957                   NaN
# 7910741                   NaN
# 6838998                   NaN
# 4804436                   NaN
# 2375083                   NaN
# 5788493                   NaN
# 4852047                   NaN
# 4845355                   NaN
# 2998271                   NaN
# 6197582                   NaN
# 4738105                   NaN
# 1297340                   NaN
# 1151859                   NaN
# 6708937                   NaN
# 1725374                   NaN
# 4268355                   NaN
# 1151392                   NaN
# 1094912                   NaN
# 6924780                   NaN
# 2558407                   NaN
# 1598666                   NaN
# 7058787                   NaN
# 2131462                   NaN
# 2976085                   NaN
# 7177245                   NaN
# 6162994                   NaN
# 6611725                   NaN
# 7870931                   NaN
# 283024                    NaN
# 2375443                   NaN
# 2372341                   NaN
# 7904812                   NaN
# 6450435                   NaN
# 609447                    NaN
# 755520                    NaN
# 7763211                   NaN
# 4220024                   NaN
# 2001092                   NaN
# 2371938                   NaN
# 1847414                   NaN
# 5301301                   NaN
# 6711416                   NaN
# 2436252                   NaN
# 594020                    NaN
# 1910973                   NaN
# 1258448                   NaN
# 6925910                   NaN
# 7958333                   NaN
# 8059283                   NaN
# 7615520                   NaN
# 7913239                   NaN
# 7886546                   NaN
# 6966756                   NaN
# 2435599                   NaN
# 5080449                   NaN
# 1471177                   NaN
# 4278897                   NaN
# 2433795                   NaN
# 3757158                   NaN
# 5322710                   NaN
# 622078                    NaN
# 5531786                   NaN
# 7958368                   NaN
# 201913                    NaN
# 2435283                   NaN
# 6709635                   NaN
# 4198457                   NaN
# 3761036                   NaN
# 5576710                   NaN
# 2433694                   NaN
# 1623970                   NaN
# 3869475                   NaN
# 1643037                   NaN
# 5082469                   NaN
# 619292                    NaN
# 4278474                   NaN
# 1909703                   NaN
# 6036926                   NaN
# 2004453                   NaN
# 4647366                   NaN
# 2437430                   NaN
# 526042                    NaN
# 3723347                   NaN
# 4575555                   NaN
# 4788112                   NaN
# 7130051                   NaN
# 2435248                   NaN
# 5033594                   NaN
# 280033                    NaN
# 1704551                   NaN
# 3561253                   NaN
# 6269975                   NaN
# 4198543                   NaN
# 5009885                   NaN
# 3572981                   NaN
# 594141                    NaN
# 3570660                   NaN
# 2558075                   NaN

# %%
df1[['contrato_id', 'dt_ref_portfolio',  'perc_retencao', 'vlr_pgto_realizado',
       'vlr_pgto_esperado', 'vlr_saldo_devedor', 'vlr_saldo_devedor_esperado',
       'dsp', 'dspp', 'flag_transacao', 'data_acao', 'acao', 'canal_email',
       'st_email', 'canal_hsm', 'st_hsm']]
# Out:
#                              contrato_id dt_ref_portfolio  perc_retencao  \
# 0       d01086d5ca765d3bad8a27b2858d5837       2020-10-15        0.20184
# 1       817274b900b4a380a448a1d9d1e36fff       2022-03-01        1.20000
# 2       c1358753bd1a14d8f561ca8be3873d78       2020-05-26        0.13296
# 3       92a07335b94dc133c07ec312e951a907       2021-11-06        0.20460
# 4       19d51ad2dd10c4fca8a4ed2e6fb0b271       2020-08-03        0.13524
# ...                                  ...              ...            ...
# 190469  1bad3c9fb292bf8e544d3cc2ab822efd       2020-03-28        0.20712
# 190470  d0ccbf1f1734febeaf02c3dc49c0b3e7       2020-11-13        0.14400
# 190471  0c8a74028bcecd56f5cabd04ce5a2114       2022-02-12        0.24000
# 190472  5d1c062ed63d54ab1d8dd11b93994a60       2021-10-08        0.19200
# 190473  3546171b9a320455c09d0c5c79c60eae       2021-01-29        0.31392
#
#         vlr_pgto_realizado  vlr_pgto_esperado  vlr_saldo_devedor  \
# 0                      0.0             122.84           38180.16
# 1                      0.0              36.91           28778.14
# 2                      0.0              38.34            5048.66
# 3                      0.0             279.97          117641.96
# 4                      0.0              41.12            4024.16
# ...                    ...                ...                ...
# 190469                 0.0             345.82           57621.19
# 190470                 0.0              16.18            4917.89
# 190471                 0.0              34.42            6382.92
# 190472                 0.0              29.82            7831.48
# 190473                 0.0             119.11           11944.16
#
#         vlr_saldo_devedor_esperado  dsp  dspp  flag_transacao   data_acao  \
# 0                         21540.52   10   213               1  2020-10-15
# 1                             0.00   60   546               0  2022-03-01
# 2                          4049.72    5    62               1  2020-05-26
# 3                         49998.19   15   110               0  2021-11-08
# 4                          2848.11    5    13               0  2020-08-03
# ...                            ...  ...   ...             ...         ...
# 190469                    61453.36    5    11               0  2020-03-30
# 190470                     4408.25   10    31               0  2020-11-13
# 190471                      946.42   30    30               0  2022-02-14
# 190472                     3085.21   30    74               0  2021-10-08
# 190473                        0.00   10    10               1  2021-01-29
#
#                           acao canal_email      st_email canal_hsm  \
# 0         campanhaparcelamento       EMAIL  NAO ENTREGUE       HSM
# 1          campanhanegativacao       EMAIL      ENTREGUE       HSM
# 2           campanhaobservacao       EMAIL  NAO ENTREGUE       HSM
# 3        campanhaboletoquitado       EMAIL  NAO ENTREGUE       HSM
# 4           campanhaobservacao       EMAIL  NAO ENTREGUE       HSM
# ...                        ...         ...           ...       ...
# 190469      campanhaobservacao       EMAIL  NAO ENTREGUE       HSM
# 190470    campanhaparcelamento       EMAIL          LIDO       HSM
# 190471  campanhaprenegativacao       EMAIL  NAO ENTREGUE     EMAIL
# 190472  campanhaprenegativacao       EMAIL  NAO ENTREGUE       HSM
# 190473    campanhaparcelamento       EMAIL      ENTREGUE       HSM
#
#               st_hsm
# 0       NAO ENTREGUE
# 1               LIDO
# 2           ENTREGUE
# 3       NAO ENTREGUE
# 4               LIDO
# ...              ...
# 190469      ENTREGUE
# 190470  NAO ENTREGUE
# 190471          LIDO
# 190472  NAO ENTREGUE
# 190473  NAO ENTREGUE
#
# [190474 rows x 16 columns]

# %% [markdown]
# #### <font color=green>  4.1.6 - gráfico de efetividade de pagamento</font>

# %%
"""
====================
Horizontal bar chart
====================

This example showcases a simple horizontal bar chart.
"""
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-5ca94633f1d0> in <module>
#      23
#      24 ax.barh(y_pos, performance, xerr=error, align='center')
# ---> 25 ax.set_yticks(y_pos, labels=people)
#      26 ax.invert_yaxis()  # labels read top-to-bottom
#      27 ax.set_xlabel('Performance')
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# TypeError: set_ticks() got an unexpected keyword argument 'labels'

# %%
performance
# Out:
# array([10.00367304, 10.42750809, 10.09280011,  8.66745522, 12.77785333])

# %%
fig,ax = plt.subplots(figsize=(20,8))
sns.lineplot(x= df2['canal_email'] , y=df2['efet_email'],
                data=df2 , ax=ax, color="#4CB391" )

ax.axhline(df2['efet_email'].mean(), color='green')
ax.set_title('Curva de engajamento x nº de acionamentos (Canal Email)')
plt.show()
print('Média de comunicacao lida {:.2f}'.format(df2['efet_email'].mean()))
# Out:
# Média de comunicacao lida0.18

# %%
fig,ax = plt.subplots(figsize=(20,8))
sns.lineplot(x= df2['canal_hsm'] , y=df2['efet_hsm'],
                data=df2 , ax=ax, color="#4CB391" )

ax.axhline(df2['efet_hsm'].mean(), color='green')
ax.set_title('Curva de engajamento x nº de acionamentos (Canal hsm)')
plt.show()
print('Média de comunicacao lida {:.2f}'.format(df2['efet_hsm'].mean()))
# Out:
# Média de comunicacao lida0.18

# %%
teste = df[(df['acao'].notna()) & (df['contrato_id']=='d01086d5ca765d3bad8a27b2858d5837') ]
teste[['contrato_id', 'dt_ref_portfolio','status_contrato','vlr_pgto_realizado','vlr_saldo_devedor','dsp', 'dspp',
  'data_acao', 'acao', 'tp_acao1','st_acao1', 'tp_acao2', 'st_acao2']]

pd.set_option('display.max_columns', None)
teste.sort_values(by='dt_ref_portfolio', ascending=True)
# Out:
#                               contrato_id dt_ref_portfolio    safra  \
# 1175489  d01086d5ca765d3bad8a27b2858d5837       2020-03-28  2020-03
# 6927080  d01086d5ca765d3bad8a27b2858d5837       2020-03-31  2020-03
# 4121969  d01086d5ca765d3bad8a27b2858d5837       2020-04-02  2020-03
# 950842   d01086d5ca765d3bad8a27b2858d5837       2020-04-07  2020-03
# 6615098  d01086d5ca765d3bad8a27b2858d5837       2020-04-15  2020-03
# 4935356  d01086d5ca765d3bad8a27b2858d5837       2020-04-30  2020-03
# 4994885  d01086d5ca765d3bad8a27b2858d5837       2020-05-10  2020-03
# 2327715  d01086d5ca765d3bad8a27b2858d5837       2020-05-19  2020-03
# 1324076  d01086d5ca765d3bad8a27b2858d5837       2020-05-31  2020-03
# 1708     d01086d5ca765d3bad8a27b2858d5837       2020-06-09  2020-03
# 7308918  d01086d5ca765d3bad8a27b2858d5837       2020-06-15  2020-03
# 2491712  d01086d5ca765d3bad8a27b2858d5837       2020-06-28  2020-03
# 1492118  d01086d5ca765d3bad8a27b2858d5837       2020-07-08  2020-03
# 6965922  d01086d5ca765d3bad8a27b2858d5837       2020-07-25  2020-03
# 3672140  d01086d5ca765d3bad8a27b2858d5837       2020-10-10  2020-03
# 67       d01086d5ca765d3bad8a27b2858d5837       2020-10-15  2020-03
# 6003379  d01086d5ca765d3bad8a27b2858d5837       2020-11-25  2020-03
# 1973905  d01086d5ca765d3bad8a27b2858d5837       2020-12-28  2020-03
# 5473478  d01086d5ca765d3bad8a27b2858d5837       2021-01-02  2020-03
# 5633110  d01086d5ca765d3bad8a27b2858d5837       2021-01-07  2020-03
# 6593345  d01086d5ca765d3bad8a27b2858d5837       2021-01-19  2020-03
# 2267830  d01086d5ca765d3bad8a27b2858d5837       2021-02-16  2020-03
# 1178849  d01086d5ca765d3bad8a27b2858d5837       2021-04-24  2020-03
# 4491995  d01086d5ca765d3bad8a27b2858d5837       2021-05-26  2020-03
# 7264332  d01086d5ca765d3bad8a27b2858d5837       2021-05-31  2020-03
# 6927055  d01086d5ca765d3bad8a27b2858d5837       2021-06-07  2020-03
# 5295701  d01086d5ca765d3bad8a27b2858d5837       2021-11-06  2020-03
# 415427   d01086d5ca765d3bad8a27b2858d5837       2021-11-13  2020-03
# 3519315  d01086d5ca765d3bad8a27b2858d5837       2021-11-16  2020-03
# 6348862  d01086d5ca765d3bad8a27b2858d5837       2022-02-28  2020-03
#
#                              nr_documento status_contrato dt_contrato  \
# 1175489  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 6927080  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 4121969  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 950842   b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 6615098  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 4935356  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 4994885  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 2327715  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 1324076  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 1708     b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 7308918  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 2491712  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 1492118  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 6965922  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 3672140  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 67       b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 6003379  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 1973905  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 5473478  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 5633110  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 6593345  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 2267830  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 1178849  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 4491995  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 7264332  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 6927055  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 5295701  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 415427   b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 3519315  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
# 6348862  b28af812018cfa98adb66499dc4019ea          Active  2020-03-11
#
#         dt_desembolso dt_vencimento       dt_wo  prazo  vlr_desembolsado  \
# 1175489    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 6927080    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 4121969    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 950842     2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 6615098    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 4935356    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 4994885    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 2327715    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 1324076    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 1708       2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 7308918    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 2491712    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 1492118    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 6965922    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 3672140    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 67         2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 6003379    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 1973905    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 5473478    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 5633110    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 6593345    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 2267830    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 1178849    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 4491995    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 7264332    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 6927055    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 5295701    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 415427     2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 3519315    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
# 6348862    2020-03-12    2021-06-11  2022-06-11  25.65          32621.67
#
#          vlr_tarifa  juros_mes  juros_diario  perc_retencao  \
# 1175489         0.0    0.09588       0.00308        0.20184
# 6927080         0.0    0.09588       0.00308        0.20184
# 4121969         0.0    0.09588       0.00308        0.20184
# 950842          0.0    0.09588       0.00308        0.20184
# 6615098         0.0    0.09588       0.00308        0.20184
# 4935356         0.0    0.09588       0.00308        0.20184
# 4994885         0.0    0.09588       0.00308        0.20184
# 2327715         0.0    0.09588       0.00308        0.20184
# 1324076         0.0    0.09588       0.00308        0.20184
# 1708            0.0    0.09588       0.00308        0.20184
# 7308918         0.0    0.09588       0.00308        0.20184
# 2491712         0.0    0.09588       0.00308        0.20184
# 1492118         0.0    0.09588       0.00308        0.20184
# 6965922         0.0    0.09588       0.00308        0.20184
# 3672140         0.0    0.09588       0.00308        0.20184
# 67              0.0    0.09588       0.00308        0.20184
# 6003379         0.0    0.09588       0.00308        0.20184
# 1973905         0.0    0.09588       0.00308        0.20184
# 5473478         0.0    0.09588       0.00308        0.20184
# 5633110         0.0    0.09588       0.00308        0.20184
# 6593345         0.0    0.09588       0.00308        0.20184
# 2267830         0.0    0.09588       0.00308        0.20184
# 1178849         0.0    0.09588       0.00308        0.20184
# 4491995         0.0    0.09588       0.00308        0.24000
# 7264332         0.0    0.09588       0.00308        0.24000
# 6927055         0.0    0.09588       0.00308        0.24000
# 5295701         0.0    0.09588       0.00308        0.24000
# 415427          0.0    0.09588       0.00308        0.24000
# 3519315         0.0    0.09588       0.00308        0.24000
# 6348862         0.0    0.09588       0.00308        0.24000
#
#          vlr_pgto_realizado  vlr_pgto_esperado  vlr_saldo_devedor  \
# 1175489                0.00             122.84           33345.34
# 6927080                0.00             122.84           33606.77
# 4121969                0.00             122.84           33782.20
# 950842                 0.00             122.84           34224.78
# 6615098                0.00             122.84           34945.00
# 4935356                0.00             122.84           35238.96
# 4994885                0.00             122.84           35754.97
# 2327715                0.00             122.84           36080.18
# 1324076                0.00             122.84           36649.35
# 1708                   0.00             122.84           36754.71
# 7308918                0.00             122.84           37170.51
# 2491712                0.00             122.84           38154.44
# 1492118                0.00             122.84           39050.72
# 6965922                0.00             122.84           39806.51
# 3672140                0.00             122.84           37686.43
# 67                     0.00             122.84           38180.16
# 6003379                0.00             122.84           38373.43
# 1973905                0.00             122.84           39596.98
# 5473478                0.00             122.84           40115.75
# 5633110                0.00             122.84           40641.30
# 6593345                0.00             122.84           41617.96
# 2267830                0.00             122.84           40978.17
# 1178849                0.00             121.92           38442.51
# 4491995                0.00             121.92           37161.60
# 7264332                0.00             121.92           37640.74
# 6927055                0.00             121.92           38143.23
# 5295701                0.00             121.92           24775.63
# 415427                 0.00             121.92           24901.19
# 3519315              120.62             121.92           24900.71
# 6348862                0.00             121.92            9820.38
#
#          vlr_saldo_devedor_esperado  dsp  dspp  flag_transacao   data_acao  \
# 1175489                    31964.86    5    12               0  2020-03-30
# 6927080                    31845.98    8    15               0  2020-03-31
# 4121969                    31766.21   10    17               0  2020-04-02
# 950842                     31564.96   15    22               0  2020-04-07
# 6615098                    31237.46   23    30               0  2020-04-15
# 4935356                    30604.70    1    45               1  2020-04-30
# 4994885                    30168.92    5    55               0  2020-05-12
# 2327715                    29766.91    5    64               1  2020-05-19
# 1324076                    29216.02    5    76               0  2020-06-02
# 1708                       28791.42    5    85               1  2020-06-09
# 7308918                    28502.77    5    91               0  2020-06-15
# 2491712                    27861.69    5   104               0  2020-06-30
# 1492118                    27353.57    5   114               1  2020-07-08
# 6965922                    26458.82    5   131               0  2020-07-27
# 3672140                    21871.40    5   208               0  2020-10-12
# 67                         21540.52   10   213               1  2020-10-15
# 6003379                    18658.50    5   254               0  2020-11-25
# 1973905                    16104.72    5   287               0  2020-12-28
# 5473478                    15698.30   10   292               0  2021-01-04
# 5633110                    15286.58   15   297               0  2021-01-07
# 6593345                    14276.29    5   309               0  2021-01-19
# 2267830                    11792.51    5   337               0  2021-02-16
# 1178849                     5087.89    5   404               0  2021-04-26
# 4491995                     1408.64    5   436               0  2021-05-26
# 7264332                      799.20   10   441               1  2021-05-31
# 6927055                        0.00    5   448               0  2021-06-07
# 5295701                        0.00    5     5               1  2021-11-08
# 415427                         0.00    5    12               0  2021-11-15
# 3519315                        0.00    0    15               1  2021-11-16
# 6348862                        0.00    5     5               0  2022-02-28
#
#                           acao tp_acao1      st_acao1 tp_acao2      st_acao2  \
# 1175489     campanhaobservacao    EMAIL          LIDO      HSM          LIDO
# 6927080     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 4121969   campanhaparcelamento    EMAIL  NAO ENTREGUE      HSM          LIDO
# 950842   campanhaboletoquitado    EMAIL          LIDO      HSM          LIDO
# 6615098   campanhaparcelamento    EMAIL      ENTREGUE      HSM      ENTREGUE
# 4935356  campanhaboletoquitado    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 4994885     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM          LIDO
# 2327715     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 1324076     campanhaobservacao    EMAIL      ENTREGUE      HSM          LIDO
# 1708        campanhaobservacao    EMAIL  NAO ENTREGUE      HSM      ENTREGUE
# 7308918     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 2491712     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 1492118     campanhaobservacao    EMAIL          LIDO      HSM      ENTREGUE
# 6965922     campanhaobservacao    EMAIL          LIDO      HSM  NAO ENTREGUE
# 3672140     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 67        campanhaparcelamento    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 6003379     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM          LIDO
# 1973905     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 5473478   campanhaparcelamento    EMAIL      ENTREGUE      HSM      ENTREGUE
# 5633110  campanhaboletoquitado    EMAIL  NAO ENTREGUE      HSM      ENTREGUE
# 6593345     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 2267830     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 1178849     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM          LIDO
# 4491995     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM      ENTREGUE
# 7264332   campanhaparcelamento    EMAIL      ENTREGUE      HSM      ENTREGUE
# 6927055     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 5295701     campanhaobservacao    EMAIL  NAO ENTREGUE      HSM  NAO ENTREGUE
# 415427      campanhaobservacao    EMAIL  NAO ENTREGUE      HSM      ENTREGUE
# 3519315     campanhaobservacao    EMAIL          LIDO      HSM          LIDO
# 6348862     campanhaobservacao    EMAIL      ENTREGUE      HSM    RESPONDIDO
#
#         dt_transacao  qtd_transacoes  vlr_tpv tipo_empresa  cidade estado  \
# 1175489          NaN             NaN      NaN           PJ  Maceió     AL
# 6927080          NaN             NaN      NaN           PJ  Maceió     AL
# 4121969          NaN             NaN      NaN           PJ  Maceió     AL
# 950842           NaN             NaN      NaN           PJ  Maceió     AL
# 6615098          NaN             NaN      NaN           PJ  Maceió     AL
# 4935356   2020-04-30             1.0    784.0           PJ  Maceió     AL
# 4994885          NaN             NaN      NaN           PJ  Maceió     AL
# 2327715   2020-05-19             1.0    750.0           PJ  Maceió     AL
# 1324076          NaN             NaN      NaN           PJ  Maceió     AL
# 1708      2020-06-09             1.0    570.0           PJ  Maceió     AL
# 7308918          NaN             NaN      NaN           PJ  Maceió     AL
# 2491712          NaN             NaN      NaN           PJ  Maceió     AL
# 1492118   2020-07-08             1.0    500.0           PJ  Maceió     AL
# 6965922          NaN             NaN      NaN           PJ  Maceió     AL
# 3672140          NaN             NaN      NaN           PJ  Maceió     AL
# 67        2020-10-15             3.0   1295.0           PJ  Maceió     AL
# 6003379          NaN             NaN      NaN           PJ  Maceió     AL
# 1973905          NaN             NaN      NaN           PJ  Maceió     AL
# 5473478          NaN             NaN      NaN           PJ  Maceió     AL
# 5633110          NaN             NaN      NaN           PJ  Maceió     AL
# 6593345          NaN             NaN      NaN           PJ  Maceió     AL
# 2267830          NaN             NaN      NaN           PJ  Maceió     AL
# 1178849          NaN             NaN      NaN           PJ  Maceió     AL
# 4491995          NaN             NaN      NaN           PJ  Maceió     AL
# 7264332   2021-05-31             1.0    430.0           PJ  Maceió     AL
# 6927055          NaN             NaN      NaN           PJ  Maceió     AL
# 5295701          NaN             NaN      NaN           PJ  Maceió     AL
# 415427           NaN             NaN      NaN           PJ  Maceió     AL
# 3519315          NaN             NaN      NaN           PJ  Maceió     AL
# 6348862          NaN             NaN      NaN           PJ  Maceió     AL
#
#         subsegmento       segmento  População estimada - pessoas [2021]  \
# 1175489       Saúde  Bens duráveis                            3365351.0
# 6927080       Saúde  Bens duráveis                            3365351.0
# 4121969       Saúde  Bens duráveis                            3365351.0
# 950842        Saúde  Bens duráveis                            3365351.0
# 6615098       Saúde  Bens duráveis                            3365351.0
# 4935356       Saúde  Bens duráveis                            3365351.0
# 4994885       Saúde  Bens duráveis                            3365351.0
# 2327715       Saúde  Bens duráveis                            3365351.0
# 1324076       Saúde  Bens duráveis                            3365351.0
# 1708          Saúde  Bens duráveis                            3365351.0
# 7308918       Saúde  Bens duráveis                            3365351.0
# 2491712       Saúde  Bens duráveis                            3365351.0
# 1492118       Saúde  Bens duráveis                            3365351.0
# 6965922       Saúde  Bens duráveis                            3365351.0
# 3672140       Saúde  Bens duráveis                            3365351.0
# 67            Saúde  Bens duráveis                            3365351.0
# 6003379       Saúde  Bens duráveis                            3365351.0
# 1973905       Saúde  Bens duráveis                            3365351.0
# 5473478       Saúde  Bens duráveis                            3365351.0
# 5633110       Saúde  Bens duráveis                            3365351.0
# 6593345       Saúde  Bens duráveis                            3365351.0
# 2267830       Saúde  Bens duráveis                            3365351.0
# 1178849       Saúde  Bens duráveis                            3365351.0
# 4491995       Saúde  Bens duráveis                            3365351.0
# 7264332       Saúde  Bens duráveis                            3365351.0
# 6927055       Saúde  Bens duráveis                            3365351.0
# 5295701       Saúde  Bens duráveis                            3365351.0
# 415427        Saúde  Bens duráveis                            3365351.0
# 3519315       Saúde  Bens duráveis                            3365351.0
# 6348862       Saúde  Bens duráveis                            3365351.0
#
#          Densidade demográfica [2010]  \
# 1175489                        112.33
# 6927080                        112.33
# 4121969                        112.33
# 950842                         112.33
# 6615098                        112.33
# 4935356                        112.33
# 4994885                        112.33
# 2327715                        112.33
# 1324076                        112.33
# 1708                           112.33
# 7308918                        112.33
# 2491712                        112.33
# 1492118                        112.33
# 6965922                        112.33
# 3672140                        112.33
# 67                             112.33
# 6003379                        112.33
# 1973905                        112.33
# 5473478                        112.33
# 5633110                        112.33
# 6593345                        112.33
# 2267830                        112.33
# 1178849                        112.33
# 4491995                        112.33
# 7264332                        112.33
# 6927055                        112.33
# 5295701                        112.33
# 415427                         112.33
# 3519315                        112.33
# 6348862                        112.33
#
#          Matrículas no ensino fundamental[2020]  IDH[2010]  \
# 1175489                                 464704.0      0.631
# 6927080                                 464704.0      0.631
# 4121969                                 464704.0      0.631
# 950842                                  464704.0      0.631
# 6615098                                 464704.0      0.631
# 4935356                                 464704.0      0.631
# 4994885                                 464704.0      0.631
# 2327715                                 464704.0      0.631
# 1324076                                 464704.0      0.631
# 1708                                    464704.0      0.631
# 7308918                                 464704.0      0.631
# 2491712                                 464704.0      0.631
# 1492118                                 464704.0      0.631
# 6965922                                 464704.0      0.631
# 3672140                                 464704.0      0.631
# 67                                      464704.0      0.631
# 6003379                                 464704.0      0.631
# 1973905                                 464704.0      0.631
# 5473478                                 464704.0      0.631
# 5633110                                 464704.0      0.631
# 6593345                                 464704.0      0.631
# 2267830                                 464704.0      0.631
# 1178849                                 464704.0      0.631
# 4491995                                 464704.0      0.631
# 7264332                                 464704.0      0.631
# 6927055                                 464704.0      0.631
# 5295701                                 464704.0      0.631
# 415427                                  464704.0      0.631
# 3519315                                 464704.0      0.631
# 6348862                                 464704.0      0.631
#
#          balanco_financeiro- R$ (×1000) [2017]  \
# 1175489                           1.489804e+06
# 6927080                           1.489804e+06
# 4121969                           1.489804e+06
# 950842                            1.489804e+06
# 6615098                           1.489804e+06
# 4935356                           1.489804e+06
# 4994885                           1.489804e+06
# 2327715                           1.489804e+06
# 1324076                           1.489804e+06
# 1708                              1.489804e+06
# 7308918                           1.489804e+06
# 2491712                           1.489804e+06
# 1492118                           1.489804e+06
# 6965922                           1.489804e+06
# 3672140                           1.489804e+06
# 67                                1.489804e+06
# 6003379                           1.489804e+06
# 1973905                           1.489804e+06
# 5473478                           1.489804e+06
# 5633110                           1.489804e+06
# 6593345                           1.489804e+06
# 2267830                           1.489804e+06
# 1178849                           1.489804e+06
# 4491995                           1.489804e+06
# 7264332                           1.489804e+06
# 6927055                           1.489804e+06
# 5295701                           1.489804e+06
# 415427                            1.489804e+06
# 3519315                           1.489804e+06
# 6348862                           1.489804e+06
#
#          Rendimento mensal domiciliar per capita - R$ [2021]  \
# 1175489                                              777.0
# 6927080                                              777.0
# 4121969                                              777.0
# 950842                                               777.0
# 6615098                                              777.0
# 4935356                                              777.0
# 4994885                                              777.0
# 2327715                                              777.0
# 1324076                                              777.0
# 1708                                                 777.0
# 7308918                                              777.0
# 2491712                                              777.0
# 1492118                                              777.0
# 6965922                                              777.0
# 3672140                                              777.0
# 67                                                   777.0
# 6003379                                              777.0
# 1973905                                              777.0
# 5473478                                              777.0
# 5633110                                              777.0
# 6593345                                              777.0
# 2267830                                              777.0
# 1178849                                              777.0
# 4491995                                              777.0
# 7264332                                              777.0
# 6927055                                              777.0
# 5295701                                              777.0
# 415427                                               777.0
# 3519315                                              777.0
# 6348862                                              777.0
#
#          Total de veículos - veículos [2021]
# 1175489                             981823.0
# 6927080                             981823.0
# 4121969                             981823.0
# 950842                              981823.0
# 6615098                             981823.0
# 4935356                             981823.0
# 4994885                             981823.0
# 2327715                             981823.0
# 1324076                             981823.0
# 1708                                981823.0
# 7308918                             981823.0
# 2491712                             981823.0
# 1492118                             981823.0
# 6965922                             981823.0
# 3672140                             981823.0
# 67                                  981823.0
# 6003379                             981823.0
# 1973905                             981823.0
# 5473478                             981823.0
# 5633110                             981823.0
# 6593345                             981823.0
# 2267830                             981823.0
# 1178849                             981823.0
# 4491995                             981823.0
# 7264332                             981823.0
# 6927055                             981823.0
# 5295701                             981823.0
# 415427                              981823.0
# 3519315                             981823.0
# 6348862                             981823.0

# %% [markdown]
# ### <font color=green>  4.2 -  CLUSTERIZAÇÃO DA BASE</font>

# %%
# Será usado o algoritmo de machine learning Kmeans para clusterização da base

# Lista do WCSS (within-cluster sum of squares)
wcss = []

# colunas que importantes para o modelo Kmeans
col_relevantes=[]

# Grádico de Elbom ele mostra o nº de cluster ideal (hiperparemetro do modelo)
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init="k-means++", n_init=10, max_iter=300)
    X1 = df[col_relevantes].iloc[ :, 1:].values
    kmeans.fit_predict(X1)
    wcss.append(kmeans.inertia_) 
        
plt.figure(1 , figsize = (16 ,5))    
plt.plot( wcss, 'ro-', label="WCSS")
plt.title("Computing WCSS for KMeans++")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.show()
# Out:
#                               contrato_id dt_ref_portfolio    safra  \
# 14136    acea538b63dad58a85ef156471a9a8ad       2021-02-28  2020-07
# 15729    acea538b63dad58a85ef156471a9a8ad       2021-01-04  2020-07
# 15741    acea538b63dad58a85ef156471a9a8ad       2022-02-22  2020-07
# 15806    acea538b63dad58a85ef156471a9a8ad       2020-10-29  2020-07
# 16019    acea538b63dad58a85ef156471a9a8ad       2020-08-22  2020-07
# ...                                   ...              ...      ...
# 7918602  acea538b63dad58a85ef156471a9a8ad       2021-10-18  2020-07
# 7918815  acea538b63dad58a85ef156471a9a8ad       2021-08-19  2020-07
# 7921687  acea538b63dad58a85ef156471a9a8ad       2021-03-08  2020-07
# 7922178  acea538b63dad58a85ef156471a9a8ad       2021-05-08  2020-07
# 7922394  acea538b63dad58a85ef156471a9a8ad       2021-07-18  2020-07
#
#                              nr_documento status_contrato dt_contrato  \
# 14136    a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
# 15729    a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
# 15741    a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
# 15806    a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
# 16019    a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
# ...                                   ...             ...         ...
# 7918602  a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
# 7918815  a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
# 7921687  a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
# 7922178  a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
# 7922394  a52d0b7f3cd77dfc2251ced3086a7b8b          Active  2020-07-11
#
#         dt_desembolso dt_vencimento       dt_wo  prazo  ...  estado  \
# 14136      2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
# 15729      2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
# 15741      2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
# 15806      2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
# 16019      2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
# ...               ...           ...         ...    ...  ...     ...
# 7918602    2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
# 7918815    2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
# 7921687    2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
# 7922178    2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
# 7922394    2020-07-14    2021-01-11  2022-01-11  10.26  ...      ND
#
#          subsegmento  segmento  População estimada - pessoas [2021]  \
# 14136         Outros  Serviços                                  NaN
# 15729         Outros  Serviços                                  NaN
# 15741         Outros  Serviços                                  NaN
# 15806         Outros  Serviços                                  NaN
# 16019         Outros  Serviços                                  NaN
# ...              ...       ...                                  ...
# 7918602       Outros  Serviços                                  NaN
# 7918815       Outros  Serviços                                  NaN
# 7921687       Outros  Serviços                                  NaN
# 7922178       Outros  Serviços                                  NaN
# 7922394       Outros  Serviços                                  NaN
#
#          Densidade demográfica [2010]  \
# 14136                             NaN
# 15729                             NaN
# 15741                             NaN
# 15806                             NaN
# 16019                             NaN
# ...                               ...
# 7918602                           NaN
# 7918815                           NaN
# 7921687                           NaN
# 7922178                           NaN
# 7922394                           NaN
#
#          Matrículas no ensino fundamental[2020]  IDH[2010]  \
# 14136                                        NaN        NaN
# 15729                                        NaN        NaN
# 15741                                        NaN        NaN
# 15806                                        NaN        NaN
# 16019                                        NaN        NaN
# ...                                          ...        ...
# 7918602                                      NaN        NaN
# 7918815                                      NaN        NaN
# 7921687                                      NaN        NaN
# 7922178                                      NaN        NaN
# 7922394                                      NaN        NaN
#
#          balanco_financeiro- R$ (×1000) [2017]  \
# 14136                                      NaN
# 15729                                      NaN
# 15741                                      NaN
# 15806                                      NaN
# 16019                                      NaN
# ...                                        ...
# 7918602                                    NaN
# 7918815                                    NaN
# 7921687                                    NaN
# 7922178                                    NaN
# 7922394                                    NaN
#
#          Rendimento mensal domiciliar per capita - R$ [2021]  \
# 14136                                                  NaN
# 15729                                                  NaN
# 15741                                                  NaN
# 15806                                                  NaN
# 16019                                                  NaN
# ...                                                    ...
# 7918602                                                NaN
# 7918815                                                NaN
# 7921687                                                NaN
# 7922178                                                NaN
# 7922394                                                NaN
#
#          Total de veículos - veículos [2021]
# 14136                                    NaN
# 15729                                    NaN
# 15741                                    NaN
# 15806                                    NaN
# 16019                                    NaN
# ...                                      ...
# 7918602                                  NaN
# 7918815                                  NaN
# 7921687                                  NaN
# 7922178                                  NaN
# 7922394                                  NaN
#
# [1246 rows x 43 columns]

# %%
info_data(df)
# Out:
#                                                       types    count  \
# contrato_id                                          object  8061006
# dt_ref_portfolio                                     object  8061006
# safra                                                object  8061006
# nr_documento                                         object  8061006
# status_contrato                                      object  8061006
# dt_contrato                                          object  8061006
# dt_desembolso                                        object  8061006
# dt_vencimento                                        object  8061006
# dt_wo                                                object  8061006
# prazo                                               float64  8061006
# vlr_desembolsado                                    float64  8061006
# vlr_tarifa                                          float64  8061006
# juros_mes                                           float64  8061006
# juros_diario                                        float64  8061006
# perc_retencao                                       float64  8061006
# vlr_pgto_realizado                                  float64  8061006
# vlr_pgto_esperado                                   float64  8061006
# vlr_saldo_devedor                                   float64  8061006
# vlr_saldo_devedor_esperado                          float64  8061006
# dsp                                                   int64  8061006
# dspp                                                  int64  8061006
# flag_transacao                                        int64  8061006
# data_acao                                            object   190474
# acao                                                 object   190474
# tp_acao1                                             object   190474
# st_acao1                                             object   190474
# tp_acao2                                             object   190474
# st_acao2                                             object   190474
# dt_transacao                                         object  2403306
# qtd_transacoes                                      float64  2403306
# vlr_tpv                                             float64  2403306
# tipo_empresa                                         object  8061006
# cidade                                               object  8061006
# estado                                               object  8061006
# subsegmento                                          object  8061006
# segmento                                             object  8061006
# População estimada - pessoas [2021]                 float64  8059760
# Densidade demográfica [2010]                         object  8059760
# Matrículas no ensino fundamental[2020]             float64  8059760
# IDH[2010]                                            object  8059760
# balanco_financeiro- R$ (×1000) [2017]                object  8059760
# Rendimento mensal domiciliar per capita - R$ [2...  float64  8059760
# Total de veículos - veículos [2021]                 float64  8059760
#
#                                                     % missing   unique  \
# contrato_id                                          0.000000    14756
# dt_ref_portfolio                                     0.000000      838
# safra                                                0.000000       18
# nr_documento                                         0.000000    14265
# status_contrato                                      0.000000        6
# dt_contrato                                          0.000000      526
# dt_desembolso                                        0.000000      355
# dt_vencimento                                        0.000000      736
# dt_wo                                                0.000000      736
# prazo                                                0.000000        8
# vlr_desembolsado                                     0.000000     8784
# vlr_tarifa                                           0.000000      772
# juros_mes                                            0.000000       28
# juros_diario                                         0.000000       28
# perc_retencao                                        0.000000     2301
# vlr_pgto_realizado                                   0.000000   111430
# vlr_pgto_esperado                                    0.000000    12643
# vlr_saldo_devedor                                    0.000000  2879232
# vlr_saldo_devedor_esperado                           0.000000  3050274
# dsp                                                  0.000000      792
# dspp                                                 0.000000      834
# flag_transacao                                       0.000000        2
# data_acao                                           97.637094      594
# acao                                                97.637094        5
# tp_acao1                                            97.637094        1
# st_acao1                                            97.637094        4
# tp_acao2                                            97.637094        2
# st_acao2                                            97.637094        4
# dt_transacao                                        70.186029      546
# qtd_transacoes                                      70.186029      608
# vlr_tpv                                             70.186029   367503
# tipo_empresa                                         0.000000        3
# cidade                                               0.000000     1501
# estado                                               0.000000       28
# subsegmento                                          0.000000       16
# segmento                                             0.000000        9
# População estimada - pessoas [2021]                  0.015457       27
# Densidade demográfica [2010]                         0.015457       27
# Matrículas no ensino fundamental[2020]              0.015457       27
# IDH[2010]                                            0.015457       26
# balanco_financeiro- R$ (×1000) [2017]                0.015457       27
# Rendimento mensal domiciliar per capita - R$ [2...   0.015457       27
# Total de veículos - veículos [2021]                  0.015457       27
#
#                                                     duplicated
# contrato_id                                            8046250
# dt_ref_portfolio                                       8060168
# safra                                                  8060988
# nr_documento                                           8046741
# status_contrato                                        8061000
# dt_contrato                                            8060480
# dt_desembolso                                          8060651
# dt_vencimento                                          8060270
# dt_wo                                                  8060270
# prazo                                                  8060998
# vlr_desembolsado                                       8052222
# vlr_tarifa                                             8060234
# juros_mes                                              8060978
# juros_diario                                           8060978
# perc_retencao                                          8058705
# vlr_pgto_realizado                                     7949576
# vlr_pgto_esperado                                      8048363
# vlr_saldo_devedor                                      5181774
# vlr_saldo_devedor_esperado                             5010732
# dsp                                                    8060214
# dspp                                                   8060172
# flag_transacao                                         8061004
# data_acao                                               189880
# acao                                                    190469
# tp_acao1                                                190473
# st_acao1                                                190470
# tp_acao2                                                190472
# st_acao2                                                190470
# dt_transacao                                           2402760
# qtd_transacoes                                         2402698
# vlr_tpv                                                2035803
# tipo_empresa                                           8061003
# cidade                                                 8059505
# estado                                                 8060978
# subsegmento                                            8060990
# segmento                                               8060997
# População estimada - pessoas [2021]                    8059733
# Densidade demográfica [2010]                           8059733
# Matrículas no ensino fundamental[2020]                8059733
# IDH[2010]                                              8059734
# balanco_financeiro- R$ (×1000) [2017]                  8059733
# Rendimento mensal domiciliar per capita - R$ [2...     8059733
# Total de veículos - veículos [2021]                    8059733

# %%
df1 = df
df1 = df1[(df1['acao'].notna())]
df1 = df1[['contrato_id', 'acao','tp_acao1','st_acao1','tp_acao2','st_acao2']]
df1.rename(columns={'tp_acao1':'canal_email','tp_acao2':'canal_hsm'}, inplace=True)
df1['canal_email'] = 1
df1['canal_hsm'] = 1
df1 = pd.get_dummies(df1, columns= ['st_acao1','st_acao2'])

# %%
df1 = df1[['contrato_id','canal_email','acao','st_acao1_LIDO']]
# df1 = df1.groupby(by='contrato_id').sum()

# %%
df1['efetividade'] = df1['st_acao1_LIDO'] / df1['canal_email']
df1
# Out:
#                               contrato_id  canal_email  \
# 67       d01086d5ca765d3bad8a27b2858d5837            1
# 161      817274b900b4a380a448a1d9d1e36fff            1
# 245      c1358753bd1a14d8f561ca8be3873d78            1
# 291      92a07335b94dc133c07ec312e951a907            1
# 317      19d51ad2dd10c4fca8a4ed2e6fb0b271            1
# ...                                   ...          ...
# 8060514  1bad3c9fb292bf8e544d3cc2ab822efd            1
# 8060551  d0ccbf1f1734febeaf02c3dc49c0b3e7            1
# 8060796  0c8a74028bcecd56f5cabd04ce5a2114            1
# 8060818  5d1c062ed63d54ab1d8dd11b93994a60            1
# 8060885  3546171b9a320455c09d0c5c79c60eae            1
#
#                            acao  st_acao1_LIDO  efetividade
# 67         campanhaparcelamento              0          0.0
# 161         campanhanegativacao              0          0.0
# 245          campanhaobservacao              0          0.0
# 291       campanhaboletoquitado              0          0.0
# 317          campanhaobservacao              0          0.0
# ...                         ...            ...          ...
# 8060514      campanhaobservacao              0          0.0
# 8060551    campanhaparcelamento              1          1.0
# 8060796  campanhaprenegativacao              0          0.0
# 8060818  campanhaprenegativacao              0          0.0
# 8060885    campanhaparcelamento              0          0.0
#
# [190474 rows x 5 columns]

# %%
x = df1[df1['canal_email']== 20]
x['efetividade'].mean()
# Out:
# nan

# %%
# Scatterplot Renda Mensal x Modelo Score4 pela visão da Variável Target
fig,ax = plt.subplots(figsize=(15,8))
sns.lineplot(x= df1['canal_email'] , y=df1['efetividade'],
                data=df1 , ax=ax)
# Out:
# <AxesSubplot:xlabel='canal_email', ylabel='efetividade'>

# %%
fig,ax = plt.subplots(figsize=(15,8))
sns.lineplot(x= df1['canal_email'] , y=df1['st_acao1_LIDO'],
                hue=df1['acao'], data=df1 , ax=ax)
# Out:
# <AxesSubplot:xlabel='canal_email', ylabel='st_acao1_LIDO'>

# %% [markdown]
# ## <font color=green>  5 -  INSIGHTS</font>
